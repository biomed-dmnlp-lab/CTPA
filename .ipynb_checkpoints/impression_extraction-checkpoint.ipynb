# %%
import pandas as pd
import numpy as np
import re
import nltk

# %% [markdown]
# ## Code for extracting "impression" section using regular expression.

# %%
df_pn = pd.read_csv("data/Potential_negative.csv")
df_pp = pd.read_csv("data/Potential_positive.csv")

# %%
impressions = []
bad_list = ['Findings were discussed','Findings discussed','Findings reported','Findings communicated',
            'findings were communicated','The above findings','Please contact the interpreting',
            'findings of the study','via telephone','recommendations were discussed','information was discussed',
            'discussed with Dr.','communicated to Dr.','reviewed with Dr.','called with these results',
            'was notified','Findings were communicated','findings were conveyed to',
            'Up-to-date CT equipment','If this radiology report', 'DLP:','CTDIvol:','have reviewed the examination',
            'Red Document','LS1R','WY2R','Fleischner','Fleischer','Resident/Fellow',
            'PowerConnect', 'PowerScribe','Workstation ID','1H',
            'Note: These guidelines do not apply','For comments and reference','For information about',
            'See below recommendations','100','80','UN1','(Incidental alert)','Findings were conveyed','Message ID',
            '____','US2','UN2','Receipt of this communication by','findings were discussed','discussed with',
            'call ED radiology', 'reported to Dr.','Orange Alert', 'Orange alert','called with these findings',
            'ED message','Please see below','Please see separate report','----','guidelines for follow-up'
            ]


def extract(df):
    impressions = []
    for index, row in df.iterrows():
        an = row['Accession Number']
        sex = row['Patient Sex']
        age = row['Patient Age']
        date = row['Ordered Date']
        report = row['Report Text']
        start = '(IMPRESSION:|Impression:)' #HOW THE IMPRESSION SECTION STARTS

        main = '((.|\n|\r)+?)' #ALL THE CONTENT INSIDE
        end = '(\n[A-Z][A-Z]+:|$|\n(?<![A-Z\d])(?!1\d{3}\b)[A-Z\d]{4,}(?![A-Z\d])|A: Solid Nodules|B: Subsolid Nodules|<6 mm|Reference:)' #HOW IMPRESSION SECTION ENDS
        m = re.search(start + main+end, report)
        if m:
            found = m.group(2)
            print("@@@@@@@@", index, "@@@@@@@")
#             print(found)
            print(" ")

            #get rid of extra whitespaces, extra newlines, tabs, etc. 

            found = found.strip() #gets rid of newlines on its own.
            found = re.sub(' +', ' ', found) 
            found = re.sub(r'(\n\s\r*)+\n', '\n', found)
            found = re.sub(r'\n \n','\n',found)
            found = re.sub(r'\n+','\n',found)
            found = re.sub(r'\t',' ',found)

            #MORE DATA CLEANING
    #         found = re.sub(r'\n_+\n','\n',found)
    #         found = re.sub(r'\n_+$','',found)

#             found = re.sub(r'(?<![!.,])\n', '.\n', found)
            found = found.strip()

            found = nltk.sent_tokenize(found)

            filtered_list = []

            for sent in found:
                if not any(x in sent for x in bad_list) and not sent == '.' and not sent == 'Single.' and not sent == 'Multiple.' and not sent == 'Multiple' and not sent == 'Single':
                    filtered_list.append(sent)
            
            print(filtered_list[-1])
            
            found = "\n".join(filtered_list)
#             print(found)
            impressions.append([an,found, sex, age, date])
        else:
            print("ERROR")
    return impressions

# %%
pn_impressions = extract(df_pn)
pp_impressions = extract(df_pp)
# Out:
# @@@@@@@@ 0 @@@@@@@
#
# There is a hiatal hernia.
# @@@@@@@@ 1 @@@@@@@
#
# The possibility of a small peripheral pulmonary embolus cannot be excluded.
# @@@@@@@@ 2 @@@@@@@
#
# There is a stable 6 mm left upper lobe nodule.
# @@@@@@@@ 3 @@@@@@@
#
# Please clinically correlate.
# @@@@@@@@ 4 @@@@@@@
#
# Pulmonary interstitial fibrosis.
# @@@@@@@@ 5 @@@@@@@
#
# Unchanged small pulmonary nodule of the right middle lobe.
# @@@@@@@@ 6 @@@@@@@
#
# Mild centrilobular and paraseptal emphysema of the upper lobes.
# @@@@@@@@ 7 @@@@@@@
#
# Among the differential diagnosis is chronic small airway disease and chronic thromboembolic pulmonary hypertension (there is mild enlargement of the main pulmonary artery).
# @@@@@@@@ 8 @@@@@@@
#
# Mild bibasilar subsegmental atelectasis.
# @@@@@@@@ 9 @@@@@@@
#
# Centrilobular emphysema.
# @@@@@@@@ 10 @@@@@@@
#
# There is also mild bibasilar bronchiectasis compared to the previous exam.
# @@@@@@@@ 11 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 12 @@@@@@@
#
# There are no pleural fluid collections.
# @@@@@@@@ 13 @@@@@@@
#
# There are emphysematous changes of the lungs.
# @@@@@@@@ 14 @@@@@@@
#
# Evaluation of segmental and subsegmental branches significantly limited due to respiratory motion artifact.
# @@@@@@@@ 15 @@@@@@@
#
# Circumferential wall thickening of urinary bladder and right ureter likely represents acute cystitis and right ureteritis in the appropriate clinical context.
# @@@@@@@@ 16 @@@@@@@
#
# No acute abnormality in the chest.
# @@@@@@@@ 17 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 18 @@@@@@@
#
# Scar or discoid atelectasis at left lung base.
# @@@@@@@@ 19 @@@@@@@
#
# Fatty liver.
# @@@@@@@@ 20 @@@@@@@
#
# Please see the CT CT scan of the abdomen and pelvis for further details.
# @@@@@@@@ 21 @@@@@@@
#
# Therefore, follow-up ultrasound or CT urogram is recommended.
# @@@@@@@@ 22 @@@@@@@
#
# Unchanged mild mediastinal lymphadenopathy.
# @@@@@@@@ 23 @@@@@@@
#
# Extensive metastatic disease to the bony thorax.
# @@@@@@@@ 24 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 25 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 26 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 27 @@@@@@@
#
# noninfectious processes.
# @@@@@@@@ 28 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 29 @@@@@@@
#
# There is a 3 mm noncalcified pulmonary nodule in the left lower lobe.
# @@@@@@@@ 30 @@@@@@@
#
# This is faintly visualized in the old exam which was performed with thicker slices.
# @@@@@@@@ 31 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 32 @@@@@@@
#
# These were present on prior study.
# @@@@@@@@ 33 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 34 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 35 @@@@@@@
#
# The thoracic spine has features of ankylosing spondylitis.
# @@@@@@@@ 36 @@@@@@@
#
# Partial collapse of the left lower lobe.
# @@@@@@@@ 37 @@@@@@@
#
# There is an indeterminate 4 mm pulmonary nodule in the right middle lobe.
# @@@@@@@@ 38 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 39 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 40 @@@@@@@
#
# There is mild interlobular septal wall thickening suggesting mild pulmonary edema.
# @@@@@@@@ 41 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 42 @@@@@@@
#
# Recommend reassessment to see if patient still qualifies for continued annual CT low dose lung screening.
# @@@@@@@@ 43 @@@@@@@
#
# There is mild centrilobular emphysema.
# @@@@@@@@ 44 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 45 @@@@@@@
#
# No new consolidation is noted.
# @@@@@@@@ 46 @@@@@@@
#
# The thickened appearance of the wall may be related to suboptimal distention of the sigmoid colon.
# @@@@@@@@ 47 @@@@@@@
#
# The largest measures 5 mm in the right upper lobe.
# @@@@@@@@ 48 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 49 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 50 @@@@@@@
#
# Triple vessel coronary artery disease.
# @@@@@@@@ 51 @@@@@@@
#
# Clear lungs.
# @@@@@@@@ 52 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 53 @@@@@@@
#
# Recommend secondary prevention of cardiovascular disease and lifestyle modifications as appropriate.
# @@@@@@@@ 54 @@@@@@@
#
# Unchanged partially calcified and partially thrombosed 1.3 cm right renal artery pseudoaneurysm.
# @@@@@@@@ 55 @@@@@@@
#
# Please correlate with congenital heart disease history and consider cardiology consultation for right heart strain/pulmonary hypertension.
# @@@@@@@@ 56 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 57 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 58 @@@@@@@
#
# No consolidation is noted.
# @@@@@@@@ 59 @@@@@@@
#
# In the differential diagnosis is community-acquired as well as atypical pneumonia.
# @@@@@@@@ 60 @@@@@@@
#
# No significant interval change is noted in the osseous metastases.
# @@@@@@@@ 61 @@@@@@@
#
# Abnormality was noted at this region on the MRI study of the thoracic spine dated 07/11/2020.
# @@@@@@@@ 62 @@@@@@@
#
# Recommend 3 months follow-up with CT of the chest for stability.
# @@@@@@@@ 63 @@@@@@@
#
# Possible subtle emphysematous changes of the lungs.
# @@@@@@@@ 64 @@@@@@@
#
# Mild splenomegaly.
# @@@@@@@@ 65 @@@@@@@
#
# A 3 mm new nodule is seen in the right upper lobe that is indeterminate.
# @@@@@@@@ 66 @@@@@@@
#
# Status post partial left pneumonectomy with unchanged cavitations in the left hemithorax with air-fluid levels.
# @@@@@@@@ 67 @@@@@@@
#
# Recommend secondary prevention of cardiovascular disease.
# @@@@@@@@ 68 @@@@@@@
#
# There is a moderate right and small left pleural effusion.
# @@@@@@@@ 69 @@@@@@@
#
# Large right-sided pleural effusion with compressive subsegmental atelectasis of the right lower lobe.
# @@@@@@@@ 70 @@@@@@@
#
# Minimal dependent atelectasis of the lung bases.
# @@@@@@@@ 71 @@@@@@@
#
# Recommend secondary prevention of perivascular disease.
# @@@@@@@@ 72 @@@@@@@
#
# assessment of the skeletal system.
# @@@@@@@@ 73 @@@@@@@
#
# Mild dependent atelectasis of the lower lobes.
# @@@@@@@@ 74 @@@@@@@
#
# Recommend keeping inferiorly lung cancer screening CT schedule.
# @@@@@@@@ 75 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 76 @@@@@@@
#
# Tiny bilateral pleural effusions are seen.
# @@@@@@@@ 77 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 78 @@@@@@@
#
# However, there is further thickening with irregularity of the posterior inferior right pleura corresponding to metastatic disease.
# @@@@@@@@ 79 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 80 @@@@@@@
#
# No consolidation of pneumonia is noted.
# @@@@@@@@ 81 @@@@@@@
#
# Unchanged peripheral coarse reticulations in both lungs of chronic interstitial lung disease.
# @@@@@@@@ 82 @@@@@@@
#
# Bibasilar subsegmental atelectasis.
# @@@@@@@@ 83 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 84 @@@@@@@
#
# Recommend follow-up noncontrast CT of the chest in 3 months for stability.
# @@@@@@@@ 85 @@@@@@@
#
# Recommend pulmonary consultation for possible bronchoscopy for further evaluation.
# @@@@@@@@ 86 @@@@@@@
#
# Gallstones as in the previous exam.
# @@@@@@@@ 87 @@@@@@@
#
# Compared to the outside CT of 06/29/2020, there is a new left adrenal gland metastasis and increase in the size of the right adrenal gland metastasis.
# @@@@@@@@ 88 @@@@@@@
#
# Cardiomegaly, moderate to large bilateral pleural effusions, and interstitial pulmonary edema.
# @@@@@@@@ 89 @@@@@@@
#
# Endotracheal and nasogastric tubes are in place.
# @@@@@@@@ 90 @@@@@@@
#
# Small loculated right-sided pleural effusion with mild subsegmental atelectasis of the right lower lobe.
# @@@@@@@@ 91 @@@@@@@
#
# Increase in the small bilateral pleural effusions.
# @@@@@@@@ 92 @@@@@@@
#
# Small volume ascites within the upper abdomen.
# @@@@@@@@ 93 @@@@@@@
#
# No malalignment of the thoracic spine is seen.
# @@@@@@@@ 94 @@@@@@@
#
# If not already performed, recommend outpatient nonemergency basis thyroid ultrasound for further evaluation.
# @@@@@@@@ 95 @@@@@@@
#
# Aberrant right subclavian artery.
# @@@@@@@@ 96 @@@@@@@
#
# Coronary artery disease and mild cardiomegaly.
# @@@@@@@@ 97 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 98 @@@@@@@
#
# Progression of bone metastases.
# @@@@@@@@ 99 @@@@@@@
#
# Mediastinal postoperative changes from the recent CABG.
# @@@@@@@@ 100 @@@@@@@
#
# There is also heavy calcification of the aortic valve consistent with aortic stenosis.
# @@@@@@@@ 101 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 102 @@@@@@@
#
# There is also unchanged left chest soft tissues scarring and postradiation lung scarring.
# @@@@@@@@ 103 @@@@@@@
#
# No pulmonary process is noted.
# @@@@@@@@ 104 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 105 @@@@@@@
#
# Fatty liver.
# @@@@@@@@ 106 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 107 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 108 @@@@@@@
#
# Minimal subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 109 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 110 @@@@@@@
#
# thorax in 3 months without contrast for resolution.
# @@@@@@@@ 111 @@@@@@@
#
# Small hiatus hernia.
# @@@@@@@@ 112 @@@@@@@
#
# Mild subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 113 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 114 @@@@@@@
#
# No pleural effusion is seen.
# @@@@@@@@ 115 @@@@@@@
#
# Mild bibasilar bronchiectasis and subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 116 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 117 @@@@@@@
#
# Minimal subsegmental atelectasis of the right middle lobe.
# @@@@@@@@ 118 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 119 @@@@@@@
#
# A pleural-based 6 mm nodule in the right middle lobe is unchanged.
# @@@@@@@@ 120 @@@@@@@
#
# Small hiatus hernia.
# @@@@@@@@ 121 @@@@@@@
#
# Nondisplaced acute fractures of the right 2nd-4th ribs and right seventh rib.
# @@@@@@@@ 122 @@@@@@@
#
# There are a few subtle groundglass patchy areas of opacification centrally in the right upper lobe that may be due to small foci of pulmonary hemorrhage, inflammatory process or infectious process.
# @@@@@@@@ 123 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 124 @@@@@@@
#
# Mild bibasilar subsegmental atelectasis.
# @@@@@@@@ 125 @@@@@@@
#
# Mild subsegmental atelectasis of the right lower lobe and lingula as in the previous exam.
# @@@@@@@@ 126 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 127 @@@@@@@
#
# Recent nondisplaced fracture of the right third lateral rib.
# @@@@@@@@ 128 @@@@@@@
#
# Mild groundglass opacification of the lung bases may be due to hypoventilation or alveolitis.
# @@@@@@@@ 129 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 130 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 131 @@@@@@@
#
# Recommend outpatient pulmonary service follow-up if not already been done.
# @@@@@@@@ 132 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 133 @@@@@@@
#
# Moderate size hiatus hernia.
# @@@@@@@@ 134 @@@@@@@
#
# Recommend outpatient nonemergency basis ultrasound of the thyroid gland for further evaluation.
# @@@@@@@@ 135 @@@@@@@
#
# Severe emphysema.
# @@@@@@@@ 136 @@@@@@@
#
# Unchanged tiny pulmonary nodules.
# @@@@@@@@ 137 @@@@@@@
#
# No new consolidation is noted.
# @@@@@@@@ 138 @@@@@@@
#
# Moderate-sized right pleural effusion and small left-sided pleural effusion.
# @@@@@@@@ 139 @@@@@@@
#
# Ectasia of the ascending thoracic aorta measuring 3.9 cm.
# @@@@@@@@ 140 @@@@@@@
#
# Mild splenomegaly.
# @@@@@@@@ 141 @@@@@@@
#
# No acute pulmonary process is noted within the visualized portions of the lungs (the most posterior inferior aspect of the lower lobes are not included in the field-of-view).
# @@@@@@@@ 142 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 143 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 144 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 145 @@@@@@@
#
# of the right arm.
# @@@@@@@@ 146 @@@@@@@
#
# Unchanged bilateral pulmonary nodules.
# @@@@@@@@ 147 @@@@@@@
#
# Partial visualization of the soft tissue swelling/hematoma to the left side of the lower neck from the recent cervical fusion procedure.
# @@@@@@@@ 148 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 149 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 150 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 151 @@@@@@@
#
# Known left breast mass.
# @@@@@@@@ 152 @@@@@@@
#
# Then if the abnormality persists, percutaneous biopsy would be recommended.
# @@@@@@@@ 153 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 154 @@@@@@@
#
# There are multiple 4 mm or less indeterminate pulmonary nodules.
# @@@@@@@@ 155 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 156 @@@@@@@
#
# Gallstones.
# @@@@@@@@ 157 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 158 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 159 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 160 @@@@@@@
#
# Recommend PET/CT for further evaluation.
# @@@@@@@@ 161 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 162 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 163 @@@@@@@
#
# Minimal dependent subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 164 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 165 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 166 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 167 @@@@@@@
#
# Mild subsegmental atelectasis of the lung bases.
# @@@@@@@@ 168 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 169 @@@@@@@
#
# Small amount of fluid and tiny bubbles of air in the right breast likely from recent intervention.
# @@@@@@@@ 170 @@@@@@@
#
# Small hiatus hernia.
# @@@@@@@@ 171 @@@@@@@
#
# Mild enteritis of the bypassed efferent loop of the gastrojejunal anastomosis noted by wall thickening circumferentially and fat stranding.
# @@@@@@@@ 172 @@@@@@@
#
# There is no evidence of pulmonary arterial emboli or acute pulmonary process.
# @@@@@@@@ 173 @@@@@@@
#
# Chronic occlusion of the proximal left subclavian artery.
# @@@@@@@@ 174 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 175 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 176 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 177 @@@@@@@
#
# Metastatic disease to bone, liver and splenic metastases as in the previous exam.
# @@@@@@@@ 178 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 179 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 180 @@@@@@@
#
# appearance.
# @@@@@@@@ 181 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 182 @@@@@@@
# first degree relative with lung cancer, or exposure to asbestos, radon, uranium).
# @@@@@@@@ 183 @@@@@@@
#
# Subsegmental atelectasis of the right middle lobe from elevation of the right hemidiaphragm.
# @@@@@@@@ 184 @@@@@@@
#
# Recommend outpatient nonemergency basis thyroid ultrasound for further evaluation.
# @@@@@@@@ 185 @@@@@@@
#
# Chronic interstitial lung disease, emphysema, and chronic pleural disease.
# @@@@@@@@ 186 @@@@@@@
#
# Cardiomegaly.
# @@@@@@@@ 187 @@@@@@@
#
# Consider outpatient cardiac echo for further evaluation.
# @@@@@@@@ 188 @@@@@@@
#
# There are 3 small indeterminate right lower lobe pulmonary nodules with the largest measuring 5 mm.
# @@@@@@@@ 189 @@@@@@@
#
# There are superficial right anterior chest and right paraspinal venous collaterals feeding the superior vena cava distal to the stenosis.
# @@@@@@@@ 190 @@@@@@@
#
# Cardiomegaly, interstitial pulmonary edema, and moderate right and small left pleural effusions.
# @@@@@@@@ 191 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 192 @@@@@@@
#
# There are 2 indeterminate pulmonary nodules in the left lower lobe with the largest measuring 8 mm.
# @@@@@@@@ 193 @@@@@@@
#
# Tiny 2 mm pulmonary nodule in the right middle lobe.
# @@@@@@@@ 194 @@@@@@@
#
# Recommend outpatient nonemergency basis ultrasound of the thyroid gland for further evaluation.
# @@@@@@@@ 195 @@@@@@@
#
# No pneumonia is seen.
# @@@@@@@@ 196 @@@@@@@
#
# Recommend outpatient nonemergency basis ultrasound of the thyroid gland for further evaluation.
# @@@@@@@@ 197 @@@@@@@
#
# No acute airspace abnormality.
# @@@@@@@@ 198 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 199 @@@@@@@
#
# In the differential diagnosis from patient's age group is multiple myeloma.
# @@@@@@@@ 200 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 201 @@@@@@@
#
# Atherosclerosis.
# @@@@@@@@ 202 @@@@@@@
#
# Old T3 vertebral body osteoporotic compression fracture.
# @@@@@@@@ 203 @@@@@@@
#
# Low lung volumes with subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 204 @@@@@@@
#
# Moderate bilateral pleural effusions, left larger than right with compressive subsegmental atelectasis of the lower lobes and lingula.
# @@@@@@@@ 205 @@@@@@@
#
# A trace amount of pleural effusion is seen bilaterally.
# @@@@@@@@ 206 @@@@@@@
#
# Unchanged pulmonary and osseous metastases.
# @@@@@@@@ 207 @@@@@@@
#
# Hypoinflation with low lung volumes, but no consolidation is noted.
# @@@@@@@@ 208 @@@@@@@
#
# Mild centrilobular emphysema.
# @@@@@@@@ 209 @@@@@@@
#
# At this time, there are no imaging findings to suggest that these are abscesses, but clinical assessment and follow-up recommended for signs of infection.
# @@@@@@@@ 210 @@@@@@@
#
# Bilateral adrenal hyperplasia.
# @@@@@@@@ 211 @@@@@@@
#
# Recommend follow-up with noncontrast CT in 3 months for stability.
# @@@@@@@@ 212 @@@@@@@
#
# There is a 2.3 cm left adrenal adenoma.
# @@@@@@@@ 213 @@@@@@@
#
# Recommend outpatient nonemergency basis ultrasound of the thyroid gland for further evaluation.
# @@@@@@@@ 214 @@@@@@@
#
# If pulmonary emboli is clinically suspected, recommend repeat examination.
# @@@@@@@@ 215 @@@@@@@
#
# Subsegmental atelectasis of the lung bases.
# @@@@@@@@ 216 @@@@@@@
#
# Superimposed pneumonia of the left lower lobe cannot be excluded.
# @@@@@@@@ 217 @@@@@@@
#
# Coarse reticulations in the periphery of the lungs consistent with chronic interstitial lung disease.
# @@@@@@@@ 218 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 219 @@@@@@@
#
# Cardiomegaly.
# @@@@@@@@ 220 @@@@@@@
#
# There is mild emphysema.
# @@@@@@@@ 221 @@@@@@@
#
# pulmonary edema is seen.
# @@@@@@@@ 222 @@@@@@@
#
# This is unchanged.
# @@@@@@@@ 223 @@@@@@@
#
# Given patient's history of cancer, recommend follow-up with noncontrast CT of the chest in 3 months for stability.
# @@@@@@@@ 224 @@@@@@@
#
# Unchanged right posterior fat-containing diaphragmatic hernia.
# @@@@@@@@ 225 @@@@@@@
#
# Bronchial dilatation/bronchiectasis of the lower lobes with subsegmental atelectasis.
# @@@@@@@@ 226 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 227 @@@@@@@
#
# Small hiatus hernia.
# @@@@@@@@ 228 @@@@@@@
#
# There is mild paraseptal emphysema in the lung apices.
# @@@@@@@@ 229 @@@@@@@
#
# No pneumonia or acute pulmonary process is noted.
# @@@@@@@@ 230 @@@@@@@
#
# Pulmonary fibrosis as in the previous exam.
# @@@@@@@@ 231 @@@@@@@
#
# Aortic valve calcifications as in the previous study.
# @@@@@@@@ 232 @@@@@@@
#
# Tiny pulmonary nodules with the largest measuring 3 mm in the right upper lobe.
# @@@@@@@@ 233 @@@@@@@
#
# Given patient's history of laryngeal cancer, recommend follow-up with noncontrast CT of the chest in 3 months.
# @@@@@@@@ 234 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 235 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 236 @@@@@@@
#
# The opacity seen in the lateral view of the chest x-ray of 01/13/2020 corresponds to subsegmental atelectasis seen medially in both upper lobes.
# @@@@@@@@ 237 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 238 @@@@@@@
#
# Indeterminate right lung small pulmonary nodules with the largest measuring 6 mm.
# @@@@@@@@ 239 @@@@@@@
#
# Moderate-sized hiatus hernia.
# @@@@@@@@ 240 @@@@@@@
#
# Large right hepatic cyst.
# @@@@@@@@ 241 @@@@@@@
#
# Unchanged 7 mm right lower lobe pulmonary nodule.
# @@@@@@@@ 242 @@@@@@@
#
# Indeterminate spiculated 1.3 cm pulmonary nodule in the right middle lobe.
# @@@@@@@@ 243 @@@@@@@
#
# Low lung volumes, but no acute pulmonary process is noted.
# @@@@@@@@ 244 @@@@@@@
#
# Patient is at risk of aspiration with fluid-filled esophagus and stomach.
# @@@@@@@@ 245 @@@@@@@
#
# Subsegmental atelectasis of the left lower lobe.
# @@@@@@@@ 246 @@@@@@@
#
# This may represent small airway disease or due to low lung volumes.
# @@@@@@@@ 247 @@@@@@@
#
# For this pulmonary nodule, see below recommendations a follow-up: .
# @@@@@@@@ 248 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 249 @@@@@@@
#
# Recommend follow-up with noncontrast CT of the chest in 3 months.
# @@@@@@@@ 250 @@@@@@@
#
# Unchanged cardiomegaly.
# @@@@@@@@ 251 @@@@@@@
#
# Mild centrilobular and paraseptal emphysema.
# @@@@@@@@ 252 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 253 @@@@@@@
#
# Diffuse fat infiltration of the liver.
# @@@@@@@@ 254 @@@@@@@
#
# A small bulla is seen in the right lower lobe medially.
# @@@@@@@@ 255 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 256 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 257 @@@@@@@
#
# Lungs are clear.
# @@@@@@@@ 258 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 259 @@@@@@@
#
# months for further evaluation.
# @@@@@@@@ 260 @@@@@@@
#
# Patchy areas of groundglass opacification in both lungs likely inflammatory or infectious.
# @@@@@@@@ 261 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 262 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 263 @@@@@@@
#
# There are esophageal venous varices, cirrhotic liver and hiatus hernia.
# @@@@@@@@ 264 @@@@@@@
#
# Platelike subsegmental atelectasis of the right middle lobe and right lower lobe with mild elevation of the right hemidiaphragm.
# @@@@@@@@ 265 @@@@@@@
#
# No significant interval change is noted in the large anterior superior mediastinal soft tissue heterogeneous mass better characterized in the previous exam and previously biopsied.
# @@@@@@@@ 266 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 267 @@@@@@@
#
# Aspiration pneumonia, community-acquired pneumonia, and atypical pneumonia are all in the differential diagnosis.
# @@@@@@@@ 268 @@@@@@@
#
# Mild subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 269 @@@@@@@
#
# Low lung volumes.
# @@@@@@@@ 270 @@@@@@@
#
# Indeterminate 3 mm pulmonary nodule in the right middle lobe.
# @@@@@@@@ 271 @@@@@@@
#
# Small hiatus hernia.
# @@@@@@@@ 272 @@@@@@@
#
# Again noted, there is a large paraesophageal hernia.
# @@@@@@@@ 273 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 274 @@@@@@@
#
# Mild bibasilar subsegmental atelectasis.
# @@@@@@@@ 275 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 276 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 277 @@@@@@@
#
# There is no evidence of pulmonary arterial emboli.
# @@@@@@@@ 278 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 279 @@@@@@@
#
# Patchy density within the left breast likely represents hematoma and air within the left breast tissue and likely expected postoperative changes of the left breast.
# @@@@@@@@ 280 @@@@@@@
#
# Due to patient's history of breast cancer, recommend follow-up CT in 3 months for stability.
# @@@@@@@@ 281 @@@@@@@
#
# There is a 4 mm indeterminate pulmonary nodule in the left lower lobe.
# @@@@@@@@ 282 @@@@@@@
#
# New 3 mm pulmonary nodule in the left lower lobe.
# @@@@@@@@ 283 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 284 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 285 @@@@@@@
#
# White blood cell count of today is normal for which infection although possible, is less likely.
# @@@@@@@@ 286 @@@@@@@
#
# Recommend outpatient nonemergency basis thyroid ultrasound for further evaluation.
# @@@@@@@@ 287 @@@@@@@
#
# No consolidation is noted.
# @@@@@@@@ 288 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 289 @@@@@@@
#
# Gallstone without cholecystitis and left adrenal adenoma.
# @@@@@@@@ 290 @@@@@@@
#
# Gallstones.
# @@@@@@@@ 291 @@@@@@@
#
# Moderate size paraesophageal hernia.
# @@@@@@@@ 292 @@@@@@@
#
# and there is a pattern of mosaic attenuation of the lungs suggesting small airway disease.
# @@@@@@@@ 293 @@@@@@@
#
# Consider outpatient nonemergency basis thyroid ultrasound for further evaluation of the thyroid gland if not already performed.
# @@@@@@@@ 294 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 295 @@@@@@@
#
# Given the chronicity since the study of January 2021, consider consultation with pulmonary service for further evaluation.
# @@@@@@@@ 296 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 297 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 298 @@@@@@@
#
# No fracture is seen.
# @@@@@@@@ 299 @@@@@@@
#
# for further evaluation.
# @@@@@@@@ 300 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 301 @@@@@@@
#
# Gallstones without cholecystitis and left nephrolithiasis without hydronephrosis.
# @@@@@@@@ 302 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 303 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 304 @@@@@@@
#
# The differential diagnosis is broad including infectious processes or reactive alveolitis.
# @@@@@@@@ 305 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 306 @@@@@@@
#
# Bandlike areas of residual opacification or scarring are seen in the location of the previously seen cavitary lesions.
# @@@@@@@@ 307 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 308 @@@@@@@
#
# No consolidation is noted.
# @@@@@@@@ 309 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 310 @@@@@@@
#
# There is pneumoperitoneum as reported in the plain film of the chest from earlier today.
# @@@@@@@@ 311 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 312 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 313 @@@@@@@
#
# Trace amount of bilateral pleural effusions is seen bilaterally without pulmonary edema.
# @@@@@@@@ 314 @@@@@@@
#
# Trace amount of bilateral pleural effusions.
# @@@@@@@@ 315 @@@@@@@
#
# Interval development of patchy hypodensities and air foci in left lung lower lobe parenchyma, suspicious for necrotizing pneumonia or lung abscess.
# @@@@@@@@ 316 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 317 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 318 @@@@@@@
#
# Small right-sided pleural effusion with minimal associated subsegmental atelectasis of the right lower lobe.
# @@@@@@@@ 319 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 320 @@@@@@@
#
# Unchanged right lung pulmonary nodules and bilateral hilar lymphadenopathy.
# @@@@@@@@ 321 @@@@@@@
#
# No pleural effusion is seen.
# @@@@@@@@ 322 @@@@@@@
#
# Mild subsegmental atelectasis.
# @@@@@@@@ 323 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 324 @@@@@@@
#
# Scattered pulmonary nodules with the largest measuring 6 cm in the right lower lobe.
# @@@@@@@@ 325 @@@@@@@
#
# Imaging features can be seen with Covid 19 pneumonia, although are nonspecific and can occur with a variety of infections and known infectious processes.
# @@@@@@@@ 326 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 327 @@@@@@@
#
# Acute to subacute mildly displaced fracture of the sixth left lateral rib.
# @@@@@@@@ 328 @@@@@@@
#
# Unchanged severe emphysema with large bullae.
# @@@@@@@@ 329 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 330 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 331 @@@@@@@
#
# Unchanged small pulmonary nodules.
# @@@@@@@@ 332 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 333 @@@@@@@
#
# No previous exam is available to compare and there is no known history of malignancy for which recommend follow-up with MRI of the abdomen with with or without contrast in 6 months.
# @@@@@@@@ 334 @@@@@@@
#
# Status post left pneumonectomy.
# @@@@@@@@ 335 @@@@@@@
#
# Contrast was injected through the left arm and shows stenosis of the left subclavian vein at the thoracic inlet with multiple left upper shoulder region venous collaterals.
# @@@@@@@@ 336 @@@@@@@
#
# Single patchy area of groundglass opacification is seen in the right lower lobe posteriorly may represent inflammatory or infectious process.
# @@@@@@@@ 337 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 338 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 339 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 340 @@@@@@@
#
# No mediastinal lymph nodes are unchanged compared to the PET/CT.
# @@@@@@@@ 341 @@@@@@@
#
# Gallstones without cholecystitis.
# @@@@@@@@ 342 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 343 @@@@@@@
#
# Severe centrilobular emphysema is again noted, but no consolidation is seen.
# @@@@@@@@ 344 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 345 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 346 @@@@@@@
#
# Bilateral ruptured contracted breast implants.
# @@@@@@@@ 347 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 348 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 349 @@@@@@@
#
# Due to patient's history, recommend follow-up with MRI of the liver with and without contrast in 3-6 months.
# @@@@@@@@ 350 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 351 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 352 @@@@@@@
#
# recent H pylori and gastroesophageal reflux disease diagnosis as per Epic, recommend upper GI consultation for endoscopy if not performed recently for further evaluation.
# @@@@@@@@ 353 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 354 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 355 @@@@@@@
#
# Moderate-sized paraesophageal hernia compared to previous study.
# @@@@@@@@ 356 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 357 @@@@@@@
#
# Was 0.
# @@@@@@@@ 358 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 359 @@@@@@@
#
# Recommend follow-up noncontrast CT of the chest in 3 months for stability.
# @@@@@@@@ 360 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 361 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 362 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 363 @@@@@@@
#
# Hepatic steatosis with cirrhotic liver morphology.
# @@@@@@@@ 364 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 365 @@@@@@@
#
# Right lung peribronchial wall thickening and distal patchy opacities and tree-in-bud opacities may represent pneumonia or peribronchial extension of malignancy.
# @@@@@@@@ 366 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 367 @@@@@@@
#
# Small hiatus hernia.
# @@@@@@@@ 368 @@@@@@@
#
# Small left pleural effusion with atelectasis/consolidation in the left lower lobe.
# @@@@@@@@ 369 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 370 @@@@@@@
#
# No pneumonia is seen.
# @@@@@@@@ 371 @@@@@@@
#
# Recommend follow-up with CT in 3 months.
# @@@@@@@@ 372 @@@@@@@
#
# Body of the sternum minimally displaced fracture and anterior nondisplaced acute rib fractures likely from the CPR.
# @@@@@@@@ 373 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 374 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 375 @@@@@@@
#
# Tiny patchy single focus of infiltration in the right lower lobe that may represent inflammatory or infectious process.
# @@@@@@@@ 376 @@@@@@@
#
# Gallstones without cholecystitis, small hiatus hernia and chronic diverticulosis.
# @@@@@@@@ 377 @@@@@@@
#
# There is mild subsegmental atelectasis of the left lower lobe.
# @@@@@@@@ 378 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 379 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 380 @@@@@@@
#
# Mild dependent atelectasis of the lower lobes and tiny bilateral pleural effusions.
# @@@@@@@@ 381 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 382 @@@@@@@
#
# Multifocal pneumonia, more pronounced in the left lung.
# @@@@@@@@ 383 @@@@@@@
#
# Right lower lobe pneumonia.
# @@@@@@@@ 384 @@@@@@@
#
# No acute cardiopulmonary process is noted.
# @@@@@@@@ 385 @@@@@@@
#
# Possible mild respiratory bronchiolitis in the upper lobes as described.
# @@@@@@@@ 386 @@@@@@@
#
# Low lung volumes, but no consolidation is noted.
# @@@@@@@@ 387 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 388 @@@@@@@
#
# Left lower lobe subsegmental atelectasis.
# @@@@@@@@ 389 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 390 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 391 @@@@@@@
#
# Minimal dependent atelectasis of the lung bases.
# @@@@@@@@ 392 @@@@@@@
#
# Cardiomegaly.
# @@@@@@@@ 393 @@@@@@@
#
# Minimal dependent atelectasis of the lower lobes.
# @@@@@@@@ 394 @@@@@@@
#
# Minimal coarse reticular markings are seen in the periphery of both lungs suggesting early chronic interstitial lung disease.
# @@@@@@@@ 395 @@@@@@@
#
# Subsegmental atelectasis of the lower lobes.
# @@@@@@@@ 396 @@@@@@@
#
# There is no evidence of pulmonary arterial emboli.
# @@@@@@@@ 397 @@@@@@@
#
# Minimal subsegmental atelectasis of the right lower lobe.
# @@@@@@@@ 398 @@@@@@@
#
# Mild diffuse fat infiltration of the liver.
# @@@@@@@@ 399 @@@@@@@
#
# Mild subsegmental atelectasis is seen in the right lower lobe and right middle lobe with elevation of the right hemidiaphragm.
# @@@@@@@@ 400 @@@@@@@
#
# There is subsegmental atelectasis of the right lower lobe.
# @@@@@@@@ 401 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 402 @@@@@@@
#
# Hepatic steatosis.
# @@@@@@@@ 403 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 404 @@@@@@@
#
# Mild centrilobular emphysema.
# @@@@@@@@ 405 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 406 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 407 @@@@@@@
#
# Patchy opacities in the upper lobes are suspicious for multifocal pneumonia.
# @@@@@@@@ 408 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 409 @@@@@@@
#
# Multifocal pneumonia of the right lung, worse compared to previous CT of August 2019.
# @@@@@@@@ 410 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 411 @@@@@@@
#
# Mild subsegmental atelectasis of the lung bases.
# @@@@@@@@ 412 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 413 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 414 @@@@@@@
#
# Unchanged osseous lesions.
# @@@@@@@@ 415 @@@@@@@
#
# Osseous lesions are unchanged.
# @@@@@@@@ 416 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 417 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 418 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 419 @@@@@@@
#
# Cirrhosis.
# @@@@@@@@ 420 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 421 @@@@@@@
#
# Recommend follow-up in 3-6 months with noncontrast CT of the chest.
# @@@@@@@@ 422 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 423 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 424 @@@@@@@
#
# There is right hilar reactive lymphadenopathy.
# @@@@@@@@ 425 @@@@@@@
#
# Right axillary scarring.
# @@@@@@@@ 426 @@@@@@@
#
# Unchanged thoracic vertebral body fractures.
# @@@@@@@@ 427 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 428 @@@@@@@
#
# Interstitial edematous pancreatitis.
# @@@@@@@@ 429 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 430 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 431 @@@@@@@
#
# No displaced acute fracture is noted.
# @@@@@@@@ 432 @@@@@@@
#
# There is diffuse moderate centrilobular emphysema.
# @@@@@@@@ 433 @@@@@@@
#
# Bibasilar subsegmental atelectasis.
# @@@@@@@@ 434 @@@@@@@
#
# There is mild subsegmental atelectasis of the right lower lobe.
# @@@@@@@@ 435 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 436 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 437 @@@@@@@
#
# No consolidation is noted.
# @@@@@@@@ 438 @@@@@@@
#
# Less than 6 mm pulmonary nodules are seen in the lung bases.
# @@@@@@@@ 439 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 440 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 441 @@@@@@@
#
# Tiny noncalcified pleural-based pulmonary nodule in the right middle lobe may represent subpleural lymph node.
# @@@@@@@@ 442 @@@@@@@
#
# There is no evidence of pulmonary arterial emboli or acute pulmonary process.
# @@@@@@@@ 443 @@@@@@@
#
# Small consolidation and/or subsegmental atelectasis in the right lower lobe.
# @@@@@@@@ 444 @@@@@@@
#
# Unchanged 2 cm left adrenal adenoma.
# @@@@@@@@ 445 @@@@@@@
#
# There are also liver lesions as seen in the CT of the abdomen from earlier today.
# @@@@@@@@ 446 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 447 @@@@@@@
#
# There is no evidence of pulmonary arterial emboli or acute pulmonary process.
# @@@@@@@@ 448 @@@@@@@
#
# No consolidation is noted.
# @@@@@@@@ 449 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 450 @@@@@@@
#
# No displaced rib fracture is noted.
# @@@@@@@@ 451 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 452 @@@@@@@
#
# There is no evidence of pulmonary arterial emboli or acute pulmonary process.
# @@@@@@@@ 453 @@@@@@@
#
# Bilateral geographic areas of groundglass opacification in the periphery of the lungs, findings commonly reported in patients with Covid 19 pneumonia.
# @@@@@@@@ 454 @@@@@@@
#
# Bilateral patchy areas of groundglass opacification are commonly reported as findings of Covid 19 pneumonia although nonspecific and can be seen with other infectious and inflammatory processes.
# @@@@@@@@ 455 @@@@@@@
#
# Minimal dependent atelectasis of the lung bases.
# @@@@@@@@ 456 @@@@@@@
#
# Multifocal pneumonia.
# @@@@@@@@ 457 @@@@@@@
#
# Recommend follow-up CT chest in 3 months for the lymphadenopathy.
# @@@@@@@@ 458 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 459 @@@@@@@
#
# Recommend correlation with symptoms and history of recent trauma.
# @@@@@@@@ 460 @@@@@@@
#
# Findings most likely represent multifocal airspace disease such as atypical pneumonia.
# @@@@@@@@ 461 @@@@@@@
#
# Trace bilateral pleural effusions.
# @@@@@@@@ 462 @@@@@@@
#
# Moderate diffuse fat infiltration of the liver.
# @@@@@@@@ 463 @@@@@@@
#
# A large left-sided pleural effusion with compressive atelectasis of the left lower lobe and moderate size right-sided pleural effusion with compressive atelectasis of the right lower lobe.
# @@@@@@@@ 464 @@@@@@@
#
# For further evaluation, recommend PET/CT as first step before percutaneous biopsy given patient's severe emphysema.
# @@@@@@@@ 465 @@@@@@@
#
# Multifocal bilateral airspace opacities are consistent with known COVID-19 pneumonia.
# @@@@@@@@ 466 @@@@@@@
#
# Enlargement of the main pulmonary artery likely related to the pulmonary hypertension.
# @@@@@@@@ 467 @@@@@@@
#
# Evaluation of the lungs is limited due to respiratory motion, but reticular and groundglass opacities are seen in the upper lobes posteriorly suspicious for multifocal pneumonia.
# @@@@@@@@ 468 @@@@@@@
#
# Trace bilateral pleural effusions and bibasilar bandlike atelectasis.
# @@@@@@@@ 469 @@@@@@@
#
# No pulmonary arterial emboli is seen.
# @@@@@@@@ 470 @@@@@@@
#
# Recommend diagnostic and therapeutic thoracentesis.
# @@@@@@@@ 471 @@@@@@@
#
# Bronchiectasis and infectious bronchiolitis of the lower lobes more pronounced in the left lower lobe with a small infiltrate of pneumonia.
# @@@@@@@@ 472 @@@@@@@
#
# Right perihilar pneumonia.
# @@@@@@@@ 473 @@@@@@@
#
# Recommend follow-up with noncontrast CT of the chest in 3 months.
# @@@@@@@@ 474 @@@@@@@
#
# Mild linear subsegmental atelectasis of the lung bases.
# @@@@@@@@ 475 @@@@@@@
#
# Severe liver steatosis.
# @@@@@@@@ 476 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 477 @@@@@@@
#
# Unchanged enlargement of the cardiac atria.
# @@@@@@@@ 478 @@@@@@@
#
# Multifocal pneumonia.
# @@@@@@@@ 479 @@@@@@@
#
# No acute cardiopulmonary process identified.
# @@@@@@@@ 480 @@@@@@@
#
# No new osseous metastases are noted.
# @@@@@@@@ 481 @@@@@@@
#
# There is also moderate to severe centrilobular emphysema.
# @@@@@@@@ 482 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 483 @@@@@@@
#
# Extensive emphysema and biapical scarring and traction bronchiectasis, unchanged.
# @@@@@@@@ 484 @@@@@@@
#
# Consider nonemergent vascular/cardiothoracic surgery consultation for management recommendations.
# @@@@@@@@ 485 @@@@@@@
#
# There are emphysematous changes of the lungs.
# @@@@@@@@ 486 @@@@@@@
#
# Unchanged right lower lobe pulmonary nodule.
# @@@@@@@@ 487 @@@@@@@
#
# Correlation with history and physical exam is suggested.
# @@@@@@@@ 488 @@@@@@@
#
# Left nephrolithiasis.
# @@@@@@@@ 489 @@@@@@@
#
# Unchanged fusiform ascending thoracic aortic aneurysm of 4.3 cm.
# @@@@@@@@ 490 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 491 @@@@@@@
#
# Lower cervical spine to upper thoracic spine partial laminectomy with associated persistent subcutaneous fat edema/fat stranding.
# @@@@@@@@ 492 @@@@@@@
#
# In the absence of trauma, osseous metastases is within the differential.
# @@@@@@@@ 493 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 494 @@@@@@@
#
# No acute process is noted in the abdomen or pelvis.
# @@@@@@@@ 495 @@@@@@@
#
# Hepatic steatosis.
# @@@@@@@@ 496 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 497 @@@@@@@
#
# .
# @@@@@@@@ 498 @@@@@@@
#
# drug toxicity and connective tissue disease, can cause a similar imaging pattern.
# @@@@@@@@ 499 @@@@@@@
#
# Unchanged ascending thoracic aortic fusiform aneurysm of 4.1 cm.
# @@@@@@@@ 500 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 501 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 502 @@@@@@@
#
# There is a small amount of right chest wall subcutaneous emphysema.
# @@@@@@@@ 503 @@@@@@@
#
# Diffusely mottled appearance of the left lateral eighth rib with surrounding soft tissue induration.
# @@@@@@@@ 504 @@@@@@@
#
# Recommend follow-up with noncontrast CT of the chest in 3 months for further evaluation.
# @@@@@@@@ 505 @@@@@@@
#
# No consolidation or other acute abnormality to explain this patient's shortness of breath.
# @@@@@@@@ 506 @@@@@@@
#
# Chronic findings as above.
# @@@@@@@@ 507 @@@@@@@
#
# Bilateral near-total atelectasis of both lung lower lobes due to compression atelectasis.
# @@@@@@@@ 508 @@@@@@@
#
# In order to ensure the presence of a significant abnormal parenchymal density in this region, follow-up chest CT scan in 3-4 months is recommended.
# @@@@@@@@ 509 @@@@@@@
#
# 4.
# @@@@@@@@ 510 @@@@@@@
#
# There is a small left pleural fluid collection.
# @@@@@@@@ 511 @@@@@@@
#
# Solitary nodule size:
# @@@@@@@@ 512 @@@@@@@
#
# Interval development of left-sided empyema, with overlying atelectasis or pneumonia.
# @@@@@@@@ 513 @@@@@@@
#
# No focal consolidation.
# @@@@@@@@ 514 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 515 @@@@@@@
#
# Imaging features can be seen with Covid 19 pneumonia, although they are nonspecific and can occur with a variety of infections and noninfectious processes.
# @@@@@@@@ 516 @@@@@@@
#
# No acute cardiopulmonary process identified.
# @@@@@@@@ 517 @@@@@@@
#
# No definite pulmonary arterial feeding vessel to indicate arteriovenous malformation.
# @@@@@@@@ 518 @@@@@@@
#
# No pulmonary artery embolism.
# @@@@@@@@ 519 @@@@@@@
#
# Tiny right-sided pleural effusion and trace amount of left-sided pleural effusion.
# @@@@@@@@ 520 @@@@@@@
#
# Suboptimal opacification of the pulmonary arteries but no evidence of pulmonary embolism to the extent visualized
# @@@@@@@@ 521 @@@@@@@
#
# No acute pulmonary or thoracic abnormality.
# @@@@@@@@ 522 @@@@@@@
#
# Loculated small to moderate right pleural effusion.
# @@@@@@@@ 523 @@@@@@@
#
# No thoracic aorta dissection.
# @@@@@@@@ 524 @@@@@@@
#
# Hepatosplenomegaly.
# @@@@@@@@ 525 @@@@@@@
#
# Solid pulmonary nodules measuring up to 4 mm are unchanged since 6/3/2019.
# @@@@@@@@ 526 @@@@@@@
#
# No acute abnormality in the abdomen or pelvis.
# @@@@@@@@ 527 @@@@@@@
#
# No acute abnormality within the lungs.
# @@@@@@@@ 528 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 529 @@@@@@@
#
# Clear lungs.
# @@@@@@@@ 530 @@@@@@@
#
# hence these guidelines do not apply to the patient's younger than 35 years.
# @@@@@@@@ 531 @@@@@@@
#
# .
# @@@@@@@@ 532 @@@@@@@
#
# Small right and trace left pleural effusion with adjacent atelectasis.
# @@@@@@@@ 533 @@@@@@@
#
# Hepatic steatosis.
# @@@@@@@@ 534 @@@@@@@
#
# 5A 3 mm nodule in the left upper lung.
# @@@@@@@@ 535 @@@@@@@
#
# There is moderate centrilobular emphysema as seen in the previous exam.
# @@@@@@@@ 536 @@@@@@@
#
# Left upper and lower lobe pneumonia with complete consolidation of the left lower lobe.
# @@@@@@@@ 537 @@@@@@@
#
# Limited study due to motion artifacts, No evidence of pulmonary embolism pulmonary arteries at least segmental level.
# @@@@@@@@ 538 @@@@@@@
#
# Advancement is recommended.
# @@@@@@@@ 539 @@@@@@@
#
# Imaging features can be seen with COVID-19 pneumonia, though are nonspecific and can occur with a variety of infectious and noninfectious processes.
# @@@@@@@@ 540 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 541 @@@@@@@
#
# Grossly unchanged large right upper lobe mass, consolidation, and osseous metastatic disease.
# @@@@@@@@ 542 @@@@@@@
#
# Small right-sided pleural effusion.
# @@@@@@@@ 543 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 544 @@@@@@@
#
# Radiographic follow-up to resolution is recommended.
# @@@@@@@@ 545 @@@@@@@
#
# There is some atelectasis at the lung bases.
# @@@@@@@@ 546 @@@@@@@
#
# Overall decrease in burden of metastatic lung disease compared to prior examination 3/20/2020 as detailed above.
# @@@@@@@@ 547 @@@@@@@
#
# There is some infiltrate/atelectasis in the left lower lobe and, possibly, along the posterior aspect of the left upper lobe.
# @@@@@@@@ 548 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 549 @@@@@@@
#
# Grade 1 anterolisthesis of C7 on T1.
# @@@@@@@@ 550 @@@@@@@
#
# No airspace disease.
# @@@@@@@@ 551 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 552 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 553 @@@@@@@
#
# Redemonstrated 4 mm left upper lobe solid nodule, unchanged since 5/4/2019.
# @@@@@@@@ 554 @@@@@@@
#
# The mid and distal pulmonary arteries are not well evaluated.
# @@@@@@@@ 555 @@@@@@@
#
# Differential includes metastatic disease.
# @@@@@@@@ 556 @@@@@@@
#
# Suboptimal opacification of the segmental pulmonary arteries but to the extent visualized, there is no pulmonary embolism seen.
# @@@@@@@@ 557 @@@@@@@
#
# Otherwise, no change in comparison to the preceding examination.
# @@@@@@@@ 558 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 559 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 560 @@@@@@@
#
# Small hiatal hernia.
# @@@@@@@@ 561 @@@@@@@
#
# No acute thoracic abnormality.
# @@@@@@@@ 562 @@@@@@@
#
# No acute abnormality.
# @@@@@@@@ 563 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 564 @@@@@@@
#
# No acute pulmonary process is seen.
# @@@@@@@@ 565 @@@@@@@
#
# Acute anterior rib fractures on the right involving the third through sixth ribs on the left involving the second through sixth ribs.
# @@@@@@@@ 566 @@@@@@@
#
# .
# @@@@@@@@ 567 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 568 @@@@@@@
#
# Incidental is made of duplicated left SVC.
# @@@@@@@@ 569 @@@@@@@
#
# Occlusion of the right bronchus intermedius with collapse of right middle and lower lobes.
# @@@@@@@@ 570 @@@@@@@
#
# Stable mild aneurysmal dilatation of the ascending thoracic aorta measuring 43 mm.
# @@@@@@@@ 571 @@@@@@@
#
# No evidence of pulmonary embolism.
# @@@@@@@@ 572 @@@@@@@
#
# No evidence of pulmonary embolism.
# @@@@@@@@ 573 @@@@@@@
#
# .
# @@@@@@@@ 574 @@@@@@@
#
# Focal consolidation/atelectasis in the anterior left lung base is consistent with residual pulmonary infarct as was seen on the CT of 11/23/2020.
# @@@@@@@@ 575 @@@@@@@
#
# Bilateral nodular groundglass opacities likely due to aspiration and/or pneumonia
# @@@@@@@@ 576 @@@@@@@
#
# There are patchy consolidation scattered throughout both lungs.
# @@@@@@@@ 577 @@@@@@@
#
# There is no acute abnormality seen in the abdomen/pelvis.
# @@@@@@@@ 578 @@@@@@@
#
# Mild bronchiectasis, tree-in-bud opacities and subtle peribronchial groundglass bilaterally suggesting bronchiolitis.
# @@@@@@@@ 579 @@@@@@@
#
# Sequela of previous pulmonary emboli with scarring at the bifurcations of bilateral lobar arteries.
# @@@@@@@@ 580 @@@@@@@
#
# Stable small pulmonary nodules since 2019.
# @@@@@@@@ 581 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 582 @@@@@@@
#
# No consolidation.
# @@@@@@@@ 583 @@@@@@@
#
# Status post cholecystectomy.
# @@@@@@@@ 584 @@@@@@@
#
# The endotracheal tube has the tip 1 cm into the right mainstem bronchus.
# @@@@@@@@ 585 @@@@@@@
#
# Multiple bilateral pulmonary nodules may be infectious or inflammatory, however given the patient's history septic emboli should be considered.
# @@@@@@@@ 586 @@@@@@@
#
# GI consult is recommended.
# @@@@@@@@ 587 @@@@@@@
#
# No airspace or interstitial lung disease.
# @@@@@@@@ 588 @@@@@@@
#
# No substantial change in right lower lobe metastatic lesion.
# @@@@@@@@ 589 @@@@@@@
#
# .
# @@@@@@@@ 590 @@@@@@@
#
# No airspace or interstitial lung disease.
# @@@@@@@@ 591 @@@@@@@
#
# This was also noted on prior study.
# @@@@@@@@ 592 @@@@@@@
#
# No pulmonary emboli are noted.
# @@@@@@@@ 593 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 594 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 595 @@@@@@@
#
# Lower lobe predominant patchy airspace opacities, some of which demonstrate centrilobular distribution can be attributed to aspiration/bronchiolitis.
# @@@@@@@@ 596 @@@@@@@
#
# A follow-up CT scan of the abdomen and pelvis with intravenous and oral contrast is recommended.
# @@@@@@@@ 597 @@@@@@@
#
# Right lung pulmonary nodules are again noted.
# @@@@@@@@ 598 @@@@@@@
#
# No central pulmonary embolus or evidence of right heart strain..
# @@@@@@@@ 599 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 600 @@@@@@@
#
# There is no fracture of the thoracic spine.
# @@@@@@@@ 601 @@@@@@@
#
# Right upper lobe 8 mm groundglass nodule is indeterminate.
# @@@@@@@@ 602 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 603 @@@@@@@
#
# Bilateral peripheral groundglass opacities in the mid to upper lungs, consistent with multifocal pneumonia secondary to known Covid infection.
# @@@@@@@@ 604 @@@@@@@
#
# ...
# @@@@@@@@ 532 @@@@@@@
#
# Nonocclusive subsegmental pulmonary emboli in the medial segment of the right lower lobe.
# @@@@@@@@ 533 @@@@@@@
#
# Findings likely in keeping with known Covid 19 pneumonia.
# @@@@@@@@ 534 @@@@@@@
#
# Right lower lobe wedge-shaped consolidations concerning for pulmonary infarcts.
# @@@@@@@@ 535 @@@@@@@
#
# Comparison with prior outside hospital examinations and close imaging follow-up is recommended.
# @@@@@@@@ 536 @@@@@@@
#
# Large volume bilateral pulmonary emboli with findings of right heart strain.
# @@@@@@@@ 537 @@@@@@@
#
# Bilateral pulmonary emboli with right heart strain.
# @@@@@@@@ 538 @@@@@@@
#
# (ED incidental finding).
# @@@@@@@@ 539 @@@@@@@
#
# Hepatic steatosis and splenomegaly.
# @@@@@@@@ 540 @@@@@@@
#
# Clinical correlation is recommended and if warranted MRI may be performed for further evaluation.
# @@@@@@@@ 541 @@@@@@@
#
# No pneumonia is noted.
# @@@@@@@@ 542 @@@@@@@
#
# There are low density filling defects, findings compatible with pulmonary emboli, extending into all of the lobar branches of both lungs.
# @@@@@@@@ 543 @@@@@@@
#
# No acute pulmonary or thoracic abnormality is seen.
# @@@@@@@@ 544 @@@@@@@
#
# No focal consolidation.
# @@@@@@@@ 545 @@@@@@@
#
# Nodular and coalescent airspace opacities in left lower lobe suspicious for Covid 19 pneumonia.
# @@@@@@@@ 546 @@@@@@@
#
# Nodular thyroid enlargement, for which dedicated outpatient thyroid ultrasound is recommended.
# @@@@@@@@ 547 @@@@@@@
#
# No acute pulmonary process.
# @@@@@@@@ 548 @@@@@@@
#
# Patchy right lower lobe peribronchial opacity concerning for aspiration pneumonia image 148 through 155 series 9.
# @@@@@@@@ 549 @@@@@@@
#
# Recommend further evaluation with renal ultrasound to assess solid versus cystic appearance of the lesion.
# @@@@@@@@ 550 @@@@@@@
#
# New peripheral, bilateral, multilobar groundglass opacities, which are consistent with an patient's known COVID-19 infection.
# @@@@@@@@ 551 @@@@@@@
#
# A 4 mm right lower lobe pulmonary nodule is indeterminate.
# @@@@@@@@ 552 @@@@@@@
#
# Stable mediastinal lymphadenopathy.
# @@@@@@@@ 553 @@@@@@@
#
# Right lower lobe consolidation, likely represents pulmonary infarct.
# @@@@@@@@ 554 @@@@@@@
#
# Evidence of mild right heart strain.
# @@@@@@@@ 555 @@@@@@@
#
# Multifocal pneumonia.
# @@@@@@@@ 556 @@@@@@@
#
# Increase in size of a small left pleural effusion with left basilar atelectasis.
# @@@@@@@@ 557 @@@@@@@
#
# Cirrhotic morphology of the liver with evidence of portal hypertension as demonstrated by splenomegaly, moderate to large volume ascites along with numerous portosystemic collaterals as described above.
# @@@@@@@@ 558 @@@@@@@
#
# Within the limits of a motion degraded examination, no evidence of new pulmonary embolism.
# @@@@@@@@ 559 @@@@@@@
#
# Follow-up CT is recommended in 3-6 months.
# @@@@@@@@ 560 @@@@@@@
#
# Bilateral lower lobe pulmonary emboli at a lobar distribution in the left.
# @@@@@@@@ 561 @@@@@@@
#
# Bilateral lower lobe pulmonary emboli.
# @@@@@@@@ 562 @@@@@@@
#
# A 5 mm right upper lobe pulmonary nodule.
# @@@@@@@@ 563 @@@@@@@
#
# Minimal right basilar atelectasis.
# @@@@@@@@ 564 @@@@@@@
#
# Follow-up is recommended.
# @@@@@@@@ 565 @@@@@@@
#
# No new pulmonary embolism or acute abnormality identified..
# @@@@@@@@ 566 @@@@@@@
#
# Increased left pleural effusion.
# @@@@@@@@ 567 @@@@@@@
#
# Right lower lobe pulmonary emboli confirmed as on recent prior abdominal CT. No evidence of right heart strain, infarct, or alveolar hemorrhage..
# @@@@@@@@ 568 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 569 @@@@@@@
#
# Nonemergent ultrasound imaging can be performed if indicated.
# @@@@@@@@ 570 @@@@@@@
#
# If not already performed, consider outpatient ultrasound evaluation.
# @@@@@@@@ 571 @@@@@@@
#
# A hypoattenuating lesion in the right hepatic lobe is unchanged compared to prior exams and was previously characterized as a hemangioma on a CT dated 11/01/2016.
# @@@@@@@@ 572 @@@@@@@
#
# Small right lower lobe subpleural pulmonary infarct.
# @@@@@@@@ 573 @@@@@@@
#
# Unchanged pulmonary nodules as seen on CT chest from 12/12/2019.
# @@@@@@@@ 574 @@@@@@@
#
# No acute abnormality within the abdomen and pelvis.
# @@@@@@@@ 575 @@@@@@@
#
# Recommend withdrawing proximal 4 cm..
# @@@@@@@@ 576 @@@@@@@
#
# Interval improvement in the previously noted multifocal pneumonia in the right lung.
# @@@@@@@@ 577 @@@@@@@
#
# No focal consolidation.
# @@@@@@@@ 578 @@@@@@@
#
# Bilateral dependent lower lobe atelectasis/consolidation.
# @@@@@@@@ 579 @@@@@@@
#
# An enlarged right hilar lymph node, likely reactive.
# @@@@@@@@ 580 @@@@@@@
#
# Small hiatal hernia.
# @@@@@@@@ 581 @@@@@@@
#
# .
# @@@@@@@@ 582 @@@@@@@
#
# A follow-up exam in 6 months is recommended to document stability.
# @@@@@@@@ 583 @@@@@@@
#
# Recommend follow-up chest CT in 3 months.
# @@@@@@@@ 584 @@@@@@@
#
# first degree relative with lung cancer, or exposure to asbestos, radon, uranium)
# @@@@@@@@ 585 @@@@@@@
#
# No focal consolidation.
# @@@@@@@@ 586 @@@@@@@
#
# No acute thoracic abnormality.
# @@@@@@@@ 587 @@@@@@@
#
# Follow-up with chest CT in 6 weeks following treatment is recommended to document resolution.
# @@@@@@@@ 588 @@@@@@@
#
# Mediastinal lymphadenopathy.
# @@@@@@@@ 589 @@@@@@@
#
# Extensive bilateral pulmonary emboli with evidence of right heart strain.
# @@@@@@@@ 590 @@@@@@@
#
# No evidence of right heart strain.
# @@@@@@@@ 591 @@@@@@@
#
# Enteric tube with its tip in the body of the stomach.
# @@@@@@@@ 592 @@@@@@@
#
# No acute abnormality within the abdomen and pelvis.
# @@@@@@@@ 593 @@@@@@@
#
# This may represent postsurgical changes however in the absence of prior imaging, phlegmon and/or mass cannot be excluded.
# @@@@@@@@ 594 @@@@@@@
#
# histologic appearance.
# @@@@@@@@ 595 @@@@@@@
#
# Infectious or inflammatory etiology such as septic emboli could also be considered.
# @@@@@@@@ 596 @@@@@@@
#
# Clinical correlation recommended for recent history of trauma.
# @@@@@@@@ 597 @@@@@@@
#
# Bibasilar airspace opacities likely representing aspiration superimposed on subsegmental atelectasis.
# @@@@@@@@ 598 @@@@@@@
#
# Constellation of findings in the heart are suggestive of right heart strain.
# @@@@@@@@ 599 @@@@@@@
#
# Persistent T11 vertebral body sclerosis is unchanged in comparison to prior CT imaging from October and November 2018.
# @@@@@@@@ 600 @@@@@@@
#
# Bilateral pulmonary edema.
# @@@@@@@@ 601 @@@@@@@
#
# Mild CT evidence of right heart strain, also identified previously.
# @@@@@@@@ 602 @@@@@@@
#
# Recommend nonemergent follow-up with renal ultrasound for further characterization.
# @@@@@@@@ 603 @@@@@@@
#
# .
# @@@@@@@@ 604 @@@@@@@
#
# No CT evidence of right heart strain.
# @@@@@@@@ 605 @@@@@@@
#
# There are several small residual right basilar subsegmental pulmonary emboli.
# @@@@@@@@ 606 @@@@@@@
#
# Unchanged bilateral metastatic disease.
# @@@@@@@@ 607 @@@@@@@
#
# No CT evidence of right heart strain.
# @@@@@@@@ 608 @@@@@@@
#
# Flattening of the interventricular septum suggests mild right heart strain.
# @@@@@@@@ 609 @@@@@@@
#
# Hepatic steatosis.
# @@@@@@@@ 610 @@@@@@@
#
# Expected evolution of juxtapleural right lower lobe infarct.
# @@@@@@@@ 611 @@@@@@@
#
# ED incidental finding.
# @@@@@@@@ 612 @@@@@@@
#
# There is associated right heart strain.
# @@@@@@@@ 613 @@@@@@@
#
# Interval resolution of previous pulmonary emboli.
# @@@@@@@@ 614 @@@@@@@
#
# 2 metallic densities in the distal esophagus are of uncertain etiology but were present on a chest x-ray from 03/04/2018, likely iatrogenic.
# @@@@@@@@ 615 @@@@@@@
#
# Right upper lobe nodules may represent pneumonia versus metastatic disease.
# @@@@@@@@ 616 @@@@@@@
#
# No evidence of right heart strain.
# @@@@@@@@ 617 @@@@@@@
#
# Follow-up to resolution is recommended after appropriate treatment.
# @@@@@@@@ 618 @@@@@@@
#
# Interval resolution of bilateral pulmonary emboli.
# @@@@@@@@ 619 @@@@@@@
#
# If unchanged at the time, no further followup is needed.
# @@@@@@@@ 620 @@@@@@@
#
# Tissue confirmation is recommended.
# @@@@@@@@ 621 @@@@@@@
#
# No evidence of pulmonary embolism.
# @@@@@@@@ 622 @@@@@@@
#
# Findings consistent with pulmonary fibrosis are less prominent compared to the prior exam.
# @@@@@@@@ 623 @@@@@@@
#
# No pleural effusion.
# @@@@@@@@ 624 @@@@@@@
#
# No pneumonia or interstitial edema.
# @@@@@@@@ 625 @@@@@@@
#
# Mildly enlarged mediastinal lymph nodes, likely reactive.
# @@@@@@@@ 626 @@@@@@@
#
# No evidence of right heart strain.
# @@@@@@@@ 627 @@@@@@@
#
# Bilateral rib and sternal fractures, attributable to CPR.
# @@@@@@@@ 628 @@@@@@@
#
# Pleural-based right lower lobe consolidation is suspicious for evolving pulmonary infarct.
# @@@@@@@@ 629 @@@@@@@
#
# This may be due to right ventricular heart strain.
# @@@@@@@@ 630 @@@@@@@
#
# Subpleural right basilar opacities likely represent pulmonary infarctions.
# @@@@@@@@ 631 @@@@@@@
#
# .
# @@@@@@@@ 632 @@@@@@@
#
# Large volume saddle pulmonary embolism, with findings of right heart strain.
# @@@@@@@@ 633 @@@@@@@
#
# Please refer to CT abdomen pelvis report from the same day dictated separately for formal findings.
# @@@@@@@@ 634 @@@@@@@
#
# The possibility of chronic infection in this region cannot be excluded although the appearance appears to be improved compared with the most recent prior study.
# @@@@@@@@ 635 @@@@@@@
#
# There is mild right heart enlargement raising the possibility of right heart strain.
# @@@@@@@@ 636 @@@@@@@
#
# Acute findings were reported to James T. Hansel, NP at 5:28 PM on the day of exam.
# @@@@@@@@ 637 @@@@@@@
#
# Interval increase in size of the adrenal nodules.
# @@@@@@@@ 638 @@@@@@@
#
# No acute abnormality within abdomen and pelvis.
# @@@@@@@@ 639 @@@@@@@
#
# No CT evidence of right heart strain.
# @@@@@@@@ 640 @@@@@@@
#
# Septic embolic disease is a less likely consideration.
# @@@@@@@@ 641 @@@@@@@
#
# Pleural-based ground glass opacity in the right lower lobe is suspicious for alveolar hemorrhage/pulmonary infarct.
# @@@@@@@@ 642 @@@@@@@
#
# Mild portal gastroenteropathy.
# @@@@@@@@ 643 @@@@@@@
#
# No evidence of right heart strain or pulmonary infarct.
# @@@@@@@@ 644 @@@@@@@
#
# Hepatic steatosis.
# @@@@@@@@ 645 @@@@@@@
#
# Rounded, patchy airspace opacities in left lower lobe with centrilobular distribution can be attributed to bronchiolitis/aspiration in the appropriate clinical context.
# @@@@@@@@ 646 @@@@@@@
#
# No airspace or interstitial pulmonary disease.
# @@@@@@@@ 647 @@@@@@@
# Subpleural fibrotic bands are present, which have been described in the absorption phase of the disease process.
# @@@@@@@@ 648 @@@@@@@
#
# No pneumonia or interstitial lung disease.
# @@@@@@@@ 649 @@@@@@@
#
# .
# @@@@@@@@ 650 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 651 @@@@@@@
#
# Bilateral pulmonary embolism with evidence of right heart strain and scattered pulmonary infarcts.
# @@@@@@@@ 652 @@@@@@@
#
# Other processes such as influenza pneumonia and organizing pneumonia, as can be seen with drug toxicity and connective tissue disease, can cause a similar pattern
# @@@@@@@@ 653 @@@@@@@
#
# No acute pulmonary process is noted.
# @@@@@@@@ 654 @@@@@@@
#
# Other processes such as influenza pneumonia and organizing pneumonia, as can be seen with drug toxicity and connective tissue disease, can cause a similar imaging pattern.
# @@@@@@@@ 655 @@@@@@@
#
# Right lower and middle lobe pulmonary embolisms.
# @@@@@@@@ 656 @@@@@@@
#
# Commonly reported imaging features of COVID-19 pneumonia are present in this patient with a known positive viral test.
# @@@@@@@@ 657 @@@@@@@
#
# Known left second through fifth rib fractures, without evidence of complete healing.
# @@@@@@@@ 658 @@@@@@@
#
# Multiple venous collaterals around the pancreas and in the region of gastric fundus with splenic vein thrombosis, unchanged.
# @@@@@@@@ 659 @@@@@@@
#
# A few hypodense lesions in liver, evaluation is suboptimal with CT PE study, likely represents known hepatic cysts, better evaluated on transplant liver ultrasound performed on 10/11/2020.
# @@@@@@@@ 660 @@@@@@@
#
# Large hiatal hernia.
# @@@@@@@@ 661 @@@@@@@
#
# Wedge-shaped area of groundglass opacity and consolidation in the left lower lobe, likely represent pulmonary infarct in the setting of pulmonary embolism.
# @@@@@@@@ 662 @@@@@@@
#
# Limited CT lower extremity venography, further evaluation with Doppler ultrasound is recommended.
# @@@@@@@@ 663 @@@@@@@
#
# No evidence of right heart strain or alveolar hemorrhage.
# @@@@@@@@ 664 @@@@@@@
#
# Alternatively atypical pneumonia is in the differential
# @@@@@@@@ 665 @@@@@@@
#
# Associated mild right heart strain.
# @@@@@@@@ 666 @@@@@@@
#
# Hepatic cirrhosis.
# @@@@@@@@ 667 @@@@@@@
#
# No acute abnormality in the abdomen or pelvis.
# @@@@@@@@ 668 @@@@@@@
#
# No pneumonia or interstitial lung disease
# @@@@@@@@ 669 @@@@@@@
#
# No evidence of right heart strain, infarct, or hemorrhage..
# @@@@@@@@ 670 @@@@@@@
#
# Debris within the proximal trachea with atelectasis and/or consolidation in the dependent portions of bilateral lower lobes suggestive of aspiration.
# @@@@@@@@ 671 @@@@@@@
#
# Wedge- shape consolidation in right posterobasal lobe is suspicious for pulmonary infarct.
# @@@@@@@@ 672 @@@@@@@
#
# Other processes such as influenza pneumonia and organizing pneumonia, as can be seen with drug toxicity and connective tissue disease, can cause a similar imaging pattern.
# @@@@@@@@ 673 @@@@@@@
#
# No evidence of right heart strain or pulmonary hemorrhage.
# @@@@@@@@ 674 @@@@@@@
#
# Small bilateral lower lobe consolidations, likely aspiration/atelectasis.
# @@@@@@@@ 675 @@@@@@@
#
# Pulmonary embolism remains in the differential.
# @@@@@@@@ 676 @@@@@@@
#
# Interval resolution of left pleural effusion with residual dense, pleural-based consolidation in left lower lobe, concerning for pulmonary
# @@@@@@@@ 677 @@@@@@@
#
# No airspace or interstitial disease.
# @@@@@@@@ 678 @@@@@@@
#
# No right heart strain.
# @@@@@@@@ 679 @@@@@@@
#
# No acute abnormality in the abdomen or pelvis.
# @@@@@@@@ 680 @@@@@@@
#
# There is evidence of right heart strain.
# @@@@@@@@ 681 @@@@@@@
#
# No acute abnormality in the abdomen and pelvis within limits of study.
# @@@@@@@@ 682 @@@@@@@
#
# No evidence of right-sided heart strain.
# @@@@@@@@ 683 @@@@@@@
#
# No significant interval change in the large right and small left pleural effusion.
# @@@@@@@@ 684 @@@@@@@
#
# Evidence of right heart strain.
# @@@@@@@@ 685 @@@@@@@
#
# No focal consolidation.
# @@@@@@@@ 686 @@@@@@@
#
# A few of these nodules show mild interval increase in size with interval development of new nodules as described.
# @@@@@@@@ 687 @@@@@@@
#
# Findings may represent infectious/inflammatory etiology, however short-term follow-up is recommended as metastases is not excluded in this patient with known metastatic esophageal cancer.
# @@@@@@@@ 688 @@@@@@@
#
# Consider nonemergent thyroid ultrasound for better characterization.
# @@@@@@@@ 689 @@@@@@@
#
# Stable widespread osseous metastatic disease.
# @@@@@@@@ 690 @@@@@@@
#
# No acute abnormality in the abdomen and pelvis.
# @@@@@@@@ 691 @@@@@@@
#
# Mild compression of superior endplate of T12 vertebral body, age indeterminant likely subacute.
# @@@@@@@@ 692 @@@@@@@
#
# Slight increase in left subpectoral lymph node now measuring 1.5 cm compared to 1.1 cm on the prior.
# @@@@@@@@ 693 @@@@@@@
#
# Small embolus in a distal subsegmental branch of the posterobasal segment of the right lower lobe.
# @@@@@@@@ 694 @@@@@@@
#
# .
# @@@@@@@@ 695 @@@@@@@
#
# There is no other significant abnormality.
# @@@@@@@@ 696 @@@@@@@
#
# Findings likely represent mild alveolar edema.
# @@@@@@@@ 697 @@@@@@@
#
# Other chronic findings as above.
# @@@@@@@@ 698 @@@@@@@
#
# A solitary segmental pulmonary embolism in the right middle lobe.
# @@@@@@@@ 699 @@@@@@@
#
# Bilateral pulmonary embolism with CT evidence of right heart strain.
# @@@@@@@@ 700 @@@@@@@
#
# In the absence of a history of malignancy follow-up can be considered with CT or MRI in 12 months.
# @@@@@@@@ 701 @@@@@@@
#
# No significant airspace or interstitial disease.
# @@@@@@@@ 702 @@@@@@@
#
# Segmental pulmonary embolism in the left upper lobe.
# @@@@@@@@ 703 @@@@@@@
#
# No evidence of pulmonary infarct.
# @@@@@@@@ 704 @@@@@@@
#
# Small pulmonary embolism in the left upper lobe
# @@@@@@@@ 705 @@@@@@@
#
# Subsegmental pulmonary embolism in the right lower lobe with associated infarct.
# @@@@@@@@ 706 @@@@@@@
#
# Evolving pulmonary infarct left upper lobe.
# @@@@@@@@ 707 @@@@@@@
#
# Two subcentimeter noncalcified right upper lobe pulmonary nodules, as described above.
# @@@@@@@@ 708 @@@@@@@
#
# Multiple healing left-sided rib fractures.
# @@@@@@@@ 709 @@@@@@@
#
# Appropriately positioned right sided chest port.
# @@@@@@@@ 710 @@@@@@@
#
# Severe hepatic steatosis

# %%
pn_impressions
# Out:
# [[26746303,
#   'No definite evidence of pulmonary embolism.\nHowever, the presence of subtle pulmonary emboli in the mid to distal pulmonary arteries cannot be absolutely excluded these vessels are not optimally opacified.\nSmall focus of probable scarring at the right lung base.\nThis was also present on prior study.\nThere is a hiatal hernia.',
#   'Male',
#   53,
#   '6/22/19 2:27'],
#  [26600585,
#   'No evidence of pulmonary embolism.\nHowever, the peripheral pulmonary arteries are not well opacified.\nThe possibility of a small peripheral pulmonary embolus cannot be excluded.',
#   'Female',
#   60,
#   '4/24/19 23:52'],
#  [27490031,
#   'No definite evidence of pulmonary embolism.\nSome of the small peripheral pulmonary artery branches in the left lower lobe are not optimally opacified making evaluation for small pulmonary emboli in these vessels difficult.\nThere are severe emphysematous changes involving the lungs.\nThere is a stable 6 mm left upper lobe nodule.',
#   'Male',
#   62,
#   '5/11/20 11:19'],
#  [26796060,
#   '1.\nWithin the limitations of this study, no evidence of pulmonary embolism.\nAs noted above, evaluation for pulmonary embolus is limited as the pulmonary arteries are not optimally opacified.\n2.\nLeft upper lobe posterior segment groundglass opacity, which may represent atelectasis or infectious/inflammatory response.\nPlease clinically correlate.\nI, James Kelly, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Sameer Hanfi, MBBS',
#   'Male',
#   71,
#   '7/15/19 1:37'],
#  [26632036,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is significant enlargement of the pulmonary arteries with the main pulmonary arterial trunk measuring 4.9 cm.\nThis is consistent with pulmonary hypertension.\n2.\nPulmonary interstitial fibrosis.',
#   'Male',
#   83,
#   '5/7/19 17:57'],
#  [26005895,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThe main pulmonary arterial trunk is borderline in size measuring 3.3 cm unchanged compared to previous exam.\nThis may be first indication of early pulmonary arterial hypertension.\n2.\nNo consolidation of pneumonia is noted.\nUnchanged small pulmonary nodule of the right middle lobe.',
#   'Female',
#   59,
#   '8/14/18 17:16'],
#  [27147041,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is enlargement of the main pulmonary arterial trunk suggesting pulmonary hypertension .\n2.\nCardiomegaly, mainly of the left ventricle and atrium.\nCoronary artery disease.\n3.\nBibasilar subsegmental atelectasis.\nMild centrilobular and paraseptal emphysema of the upper lobes.',
#   'Male',
#   60,
#   '12/2/19 17:57'],
#  [28422576,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nThere is an increase in the previously seen small left-sided pleural effusion to moderate in size.\nThere is mild subsegmental atelectasis of the lingula and left lower lobe.\n3.\nThere is cardiomegaly as in the previous exam, but no pulmonary edema is noted in the current study.\nThere is a mild pattern of mosaic attenuation better demonstrated in the current exam without interstitial pulmonary edema compared to previous \nstudy.\nAmong the differential diagnosis is chronic small airway disease and chronic thromboembolic pulmonary hypertension (there is mild enlargement of the main pulmonary artery).\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 13.7 mGy.\nDLP: 860 mGy-cm.The following accession numbers are related to this dose report 28422576:28422575',
#   'Female',
#   69,
#   '6/17/21 22:07'],
#  [27583450,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is enlargement of the main pulmonary arterial trunk measuring 3.8 cm suggesting pulmonary hypertension.\n2.\nNonspecific right hilar lymphadenopathy.\nRecommend follow-up CT in 3 months for stability.\n3.\nThere is severe emphysema of the upper lobes.\nMild bibasilar subsegmental atelectasis.',
#   'Female',
#   61,
#   '7/1/20 16:56'],
#  [27314860,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is enlargement of the main pulmonary arterial trunk increased compared to previous exam corresponding to pulmonary hypertension.\n2.\nCardiomegaly.\nPulmonary edema with moderate right-sided pleural effusion with compressive subsegmental atelectasis of the right lower lobe, and tiny left-sided pleural effusion.\n3.\nCentrilobular emphysema.',
#   'Male',
#   80,
#   '1/31/20 18:57'],
#  [26701082,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThe main pulmonary arterial trunk is enlarged measuring 3.5 cm is seen in the old exam of 2014 suggestive of pulmonary hypertension.\n2.\nMild bibasilar subsegmental atelectasis.\nThere is also mild bibasilar bronchiectasis compared to the previous exam.',
#   'Female',
#   66,
#   '6/4/19 17:19'],
#  [25936134,
#   '1.\nThe bolus of contrast is suboptimal for evaluation of the segmental branches of the pulmonary arteries, but the pulmonary arteries centrally to the lobar level show no evidence of emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   71,
#   '7/14/18 20:28'],
#  [26445228,
#   'Evaluation for pulmonary embolus is limited as the pulmonary arteries are not well opacified.\nThere is no significant infiltrate.\nThere are no pleural fluid collections.',
#   'Male',
#   40,
#   '2/24/19 1:22'],
#  [28236366,
#   'There is no definite pulmonary embolus seen.\nThe peripheral pulmonary arteries in the lower lobes are not optimally visualized due to what appears to be motion artifact.\nThere is some atelectasis at the lung bases.\nThere is some subtle septal thickening in the lungs.\nThe possibility of slight interstitial edema cannot be excluded but is not definite.\nThere are emphysematous changes of the lungs.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW12\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 21.9 mGy.\nDLP: 1378 mGy-cm.',
#   'Female',
#   92,
#   '4/8/21 20:19'],
#  [28160196,
#   '1.\nWithin the limitations of motion artifact there is no acute traumatic injury within chest abdomen pelvis or thoracolumbar spine.\n2.\nBilateral lower lobe airspace opacities may represent aspiration versus infection.\n3.\nNo pulmonary embolism within main pulmonary artery and its right and left branches.\nEvaluation of segmental and subsegmental branches significantly limited due to respiratory motion artifact.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW16\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 30.4 mGy.\nDLP: 2816 mGy-cm.The following accession numbers are related to this dose report 28160199:281601982816019728160196\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 30.4 mGy.\nDLP: 2816 mGy-cm.The following accession numbers are related to this dose report 28160197:281601992816019828160196\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 30.4 mGy.\nDLP: 2816 mGy-cm.The following accession numbers are related to this dose report 28160198:281601992816019728160196\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 30.4 mGy.\nDLP: 2816 mGy-cm.The following accession numbers are related to this dose report 28160196:281601992816019828160197',
#   'Male',
#   78,
#   '3/10/21 22:23'],
#  [28148191,
#   '1.\nThere are bilateral groundglass and patchy airspace opacities, most prominent in left lung base, likely represents a combination of aspiration and atelectasis.\n2.\nNo pulmonary embolism in major pulmonary arteries.\nSegmental and subsegmental branches cannot be assessed due to motion artifacts.\n3.\nA 9 mm obstructive radiopaque calculus in the right mid ureter with moderate upstream hydroureteronephrosis.\n4.\nHypoattenuation right kidney parenchyma with a few ill-defined scattered hypodensities, likely presents delayed nephrogram and suspicious for developing pyelonephritis.\nCorrelate with urinalysis.\n5.\nCircumferential wall thickening of urinary bladder and right ureter likely represents acute cystitis and right ureteritis in the appropriate clinical context.\nI, Ganesh Joshi, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Zeynep Vardar\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: LS1RADW03E\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 4.9 - 14.7 mGy.\nDLP: 1127 mGy-cm.',
#   'Male',
#   21,
#   '3/5/21 23:29'],
#  [28075985,
#   'Severely limited study secondary to motion artifact.\nNo pulmonary embolism in central and segmental pulmonary arteries.\nNo acute abnormality in the chest.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:William Juan, MD\r\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: LS1RADW03E',
#   'Male',
#   64,
#   '2/5/21 2:12'],
#  [27962241,
#   'Suboptimal examination due to body habitus and motion artifacts.\n1.\nNo pulmonary embolism in the pulmonary artery and its major branches.\n2.\nNo airspace or interstitial disease.\nI, Carolyn Dupuis, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Zeynep Vardar',
#   'Female',
#   32,
#   '12/13/20 21:08'],
#  [26237232,
#   '1.\nExam suboptimal, suboptimal opacification of the pulmonary artery, the main pulmonary arteries are properly and uniformly enhanced, no large filling defects found, the distal small branches not well enhanced for proper assessment.\n2.\nNo suspicious lung mass, there is 5 mm lung nodule, this is a high-risk patient, may consider follow-up CT scan in 6-12 months.\n3.\nScar or discoid atelectasis at left lung base.',
#   'Female',
#   51,
#   '11/25/18 14:02'],
#  [26703791,
#   '1.\nThe bolus of contrast is suboptimal for evaluation of the segmental or subsegmental branches of the pulmonary arteries, but no pulmonary artery are noted to the lobar level.\n2.\nNo acute pulmonary process is seen.\n3.\nFatty liver.',
#   'Male',
#   53,
#   '6/5/19 14:50'],
#  [26861398,
#   'No evidence of prominent central pulmonary embolism.\nThe presence of a subtle pulmonary embolus in the left lower lobe pulmonary artery cannot be excluded, image 103, series 6.\nThe peripheral right lower lobe pulmonary arteries are difficult to evaluate due to the prominent lung consolidation in this region.\nThere is prominent pulmonary parenchymal consolidation involving the lower lobes.\nFollow-up to resolution is needed.\nThere is a focal area of abnormal density involving the lingula region.\nThis is nonspecific.\nFollow-up is recommended.\nHealing/healed right fourth rib fracture.\nAdditional right rib irregularities are likely on a postsurgical basis.\nThere is a prominent fluid-filled esophagus.\nThe stomach is also fluid-filled and distended.\nPlease see the CT CT scan of the abdomen and pelvis for further details.',
#   'Male',
#   58,
#   '8/10/19 4:52'],
#  [26504422,
#   'No evidence of pulmonary embolism.It should be noted that the more peripheral branches of the pulmonary arteries are not well visualized due to suboptimal opacification.\nPulmonary emboli in these regions cannot be excluded.\nThere are no significant abnormal pulmonary parenchymal opacities.\nThere are low density lesions present in the renal cortices bilaterally.\nThese may represent renal cysts although some of these lesions are difficult to fully characterize at this time.\nTherefore, follow-up ultrasound or CT urogram is recommended.\nI, James Kelly, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Marcos Bachman, M.D.',
#   'Male',
#   54,
#   '3/18/19 0:12'],
#  [26556473,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nUnchanged findings of chronic interstitial lung disease.\nSmall patchy area of consolidation is seen in the right middle lobe near the major fissure that may be part of the increased interstitial lung disease.\nRecommend follow-up with noncontrast \nCT in 3 months for stability.\n3.\nUnchanged mild mediastinal lymphadenopathy.',
#   'Male',
#   76,
#   '4/6/19 17:08'],
#  [28051766,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nLarge right hilar to upper lobe mass measuring up to 8.2 cm causing extrinsic compression of the right upper lobe bronchus and occlusion of the right middle lobe and right lower lobe bronchus with collapse of right middle lobe and right lower lobe.\nThere is also extrinsic mass effect over the right upper lobe pulmonary arteries.\nThere is significant mediastinal lymphadenopathy.\nA large right-sided pleural effusion is noted.\nFindings are consistent with malignancy, likely lung carcinoma.\nRecommend pulmonary consultation for diagnosis by bronchoscopy.\n3.\nExtensive metastatic disease to the bony thorax.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or if unavailable (e.g.\nafter hours) call ED radiology at 508-421-1299 as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13',
#   'Male',
#   70,
#   '1/25/21 17:14'],
#  [26865640,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild prominence of the main pulmonary arterial trunk that may represent pulmonary hypertension.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   39,
#   '8/12/19 17:16'],
#  [26563876,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   57,
#   '4/9/19 16:40'],
#  [26486514,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild enlargement of the main pulmonary arterial trunk that may represent pulmonary hypertension.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   47,
#   '3/12/19 21:31'],
#  [28638402,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nThere is diffuse pattern of patchy predominantly peribronchial groundglass opacities, more pronounced in the lung bases.\nImaging features can be seen with Covid 19 pneumonia, although are nonspecific and can occur with a variety of infectious and \nnoninfectious processes.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 45.4 mGy.\nDLP: 3047 mGy-cm.',
#   'Male',
#   43,
#   '9/6/21 17:08'],
#  [28275525,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 5.4 - 7.4 mGy.\nDLP: 220 mGy-cm.',
#   'Female',
#   18,
#   '4/24/21 20:40'],
#  [27935854,
#   "1.\nThere is patient's produced respiratory motion artifact, but no pulmonary arterial emboli are noted.\n2.\nNo acute pulmonary process is noted.\n3.\nThere is a 3 mm noncalcified pulmonary nodule in the left lower lobe.\nPlease see below recommendations of follow-up: \nFleischner Society 2017 Guidelines for Management of Incidentally Detected Pulmonary Nodules in Adults",
#   'Male',
#   53,
#   '12/1/20 19:07'],
#  [26603176,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nSpiculated indeterminate opacity in the right lower lobe associated to bronchi of the right lower lobe posteriorly measuring up to 1.5 cm.\nAlthough this may represent a scar from a previous insult, the spiculated nature of the opacity warrants \nworkup.\nThis is faintly visualized in the old exam which was performed with thicker slices.\nSee below recommendations for follow-up:\nFleischner Society 2017 Guidelines for Management of Incidentally Detected Pulmonary Nodules in Adults',
#   'Female',
#   39,
#   '4/25/19 15:40'],
#  [26597276,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nCoronary artery disease noted by coronary artery calcification.\nRecommend secondary prevention of cardiovascular disease.\n3.\nNo acute pulmonary process is noted.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Sameer Hanfi, MBBS',
#   'Male',
#   59,
#   '4/23/19 19:39'],
#  [28764713,
#   'There is no definite pulmonary embolus seen although evaluation for pulmonary embolus is limited due to the fact that the pulmonary arteries are not optimally enhanced.\nThe more peripheral pulmonary arteries are difficult to evaluate.\nThere is no significant pneumonia seen at this time.\nThere has been a decrease in abnormal opacities in the left lower lobe and along the posterior aspect of the left upper lobe compared with prior study.\nThis may indicate resolving/resolved small \nregions of pneumonia.\nFocal regions of abnormal opacity in the right middle lobe and lingula may represent areas of atelectasis/scarring.\nThese were present on prior study.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW12\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 1.8 - 17.0 mGy.\nDLP: 1067 mGy-cm.The following accession numbers are related to this dose report 28764713:28764714',
#   'Male',
#   62,
#   '10/20/21 20:05'],
#  [28686529,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nFusiform ascending thoracic aortic aneurysm of 4.5 cm.\n3.\nNo acute pulmonary process is noted.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: LS1RADW09E\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 52.0 mGy.\nDLP: 3095 mGy-cm.The following accession numbers are related to this dose report 28686529:286865302868650228686501',
#   'Male',
#   81,
#   '9/22/21 22:15'],
#  [28240423,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.5 - 18.2 mGy.\nDLP: 509 mGy-cm.',
#   'Female',
#   43,
#   '4/10/21 19:58'],
#  [28057501,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild enlargement of the main pulmonary arterial trunk suggesting pulmonary hypertension.\n2.\nLarge right-sided pleural effusion and moderate-sized left pleural effusion with compressive subsegmental atelectasis of the lower lobes.\n3.\nSubtle patchy areas of groundglass opacification in the right middle lobe may be due to pulmonary hemorrhage (history of hemoptysis), or infectious or allergic reactive alveolitis.\n4.\nCardiomegaly.\nUnchanged 4.1 cm fusiform ascending thoracic aortic aneurysm.\n5.\nAcute transverse fracture of the superior endplate of T9 with less than 5% loss of vertebral height.\nThere is involvement of the bilateral osteophytes and anterior spinal ligament ossification anterior band with mild widening of the disc space, but no fracture through the posterior wall of the vertebral body or retropulsed bone is noted (AOSpine T9:A1B3).\nNo malalignment or involvement of the posterior band is seen.\nThe thoracic spine has features of ankylosing spondylitis.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13',
#   'Male',
#   80,
#   '1/27/21 15:38'],
#  [27578083,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNonspecific nodular to ill-defined opacities with subtle groundglass component in both lungs predominantly in the upper lobes.\nThis is nonspecific, but suggest infectious process.\n3.\nPartial collapse of the left lower lobe.',
#   'Male',
#   54,
#   '6/29/20 20:44'],
#  [27158677,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nMild subsegmental atelectases of the lingula.\nThere is a trace amount of left sided pleural effusion.\n3.\nThere is an indeterminate 4 mm pulmonary nodule in the right middle lobe.\nSee below recommendations for follow-up: \nFleischner Society 2017 Guidelines for Management of Incidentally Detected Pulmonary Nodules in Adults',
#   'Male',
#   59,
#   '12/5/19 21:38'],
#  [27017115,
#   '1.\nNo pulmonary arterial emboli is noted.\n2.\nNo acute pulmonary process is seen.',
#   'Male',
#   50,
#   '10/13/19 18:47'],
#  [26933777,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   58,
#   '9/10/19 15:27'],
#  [26693719,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nCardiomegaly mainly by enlargement of the atria.\n3.\nThere is mild interlobular septal wall thickening suggesting mild pulmonary edema.',
#   'Female',
#   77,
#   '6/1/19 20:40'],
#  [26486280,
#   '1.\nAlthough there is beam hardening artifact over the right main pulmonary artery from high concentration of contrast in the superior vena cava, the examination is diagnostic showing no filling defects in the pulmonary arteries to suggest emboli.\n2.\nNo acute pulmonary process is noted.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Uday Malhotra, M.D.',
#   'Female',
#   38,
#   '3/12/19 17:09'],
#  [26194199,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nMild subsegmental atelectasis of the lingula.\nThere is coronary artery disease noted by coronary artery calcifications.\n3.\nPatient was previously followed with CT low dose lung screening.\nRecommend reassessment to see if patient still qualifies for continued annual CT low dose lung screening.\nA Incidental - UN ED actionable finding has been sent via the PowerScribe 360 | Critical Result system on 11/5/2018 5:50 PM.\nReceipt of this communication by the responsible provider will be documented in PowerScribe 360 upon receiving acknowledgement, \nMessage ID 3082673',
#   'Female',
#   75,
#   '11/5/18 17:01'],
#  [26016115,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild enlargement of the main pulmonary arterial trunk that may represent early findings of pulmonary hypertension.\n2.\nMild cardiomegaly.\nSmall hiatus hernia.\n3.\nNo acute pulmonary process is noted.\nThere is mild centrilobular emphysema.',
#   'Female',
#   85,
#   '8/19/18 20:05'],
#  [25984729,
#   "1.\nEvaluation of the segmental branches of the pulmonary arteries is limited by a combination of factors: Quantum mottle by patient's body habitus, suboptimal contrast enhancement follow, and patient's produced respiratory motion artifact.\nHowever, the \npulmonary arteries to the lobar level show no filling defects to suggest central emboli.\n2.\nNo acute pulmonary process is noted.",
#   'Female',
#   46,
#   '8/5/18 20:19'],
#  [25653102,
#   "1.\nThere is no evidence of pulmonary arterial emboli.\nThere is pulmonary hypertension noted by enlarged pulmonary arteries as seen in the previous exam.\n2.\nElongated opacity of the left upper lobe at the area patient's tumor is unchanged.\nThere is increased lymphadenopathy in the right hilum and subcarinal space compared to previous exam.\n3.\nThere is unchanged emphysema and chronic interstitial disease as described.\nNo new consolidation is noted.",
#   'Female',
#   87,
#   '3/20/18 15:10'],
#  [26844473,
#   'Although there is no definite prominent pulmonary embolus seen, the presence of a subtle small pulmonary embolus in a right lower lobe pulmonary artery, image 201, series 02, cannot be excluded.\nThere is fatty infiltration of the liver.\nThe urinary bladder is full.\nThere is some mild thickening involving the wall of the urinary bladder.\nThis is nonspecific.\nThe wall of the sigmoid colon appears to be slightly thick, diffusely.\nThere is no adjacent edema/inflammation.\nThe thickened appearance of the wall may be related to suboptimal distention of the sigmoid colon.',
#   'Male',
#   40,
#   '8/3/19 6:56'],
#  [26607572,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo pneumonia is noted.\nThere are 3 small pulmonary nodules that are indeterminate.\nThe largest measures 5 mm in the right upper lobe.\nPlease see below recommendations for follow-up:\nFleischner Society 2017 Guidelines for Management of Incidentally Detected Pulmonary Nodules in Adults',
#   'Female',
#   48,
#   '4/27/19 21:37'],
#  [26452510,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   50,
#   '2/26/19 21:40'],
#  [26261033,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   32,
#   '12/4/18 22:50'],
#  [25990513,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nThere are low lung volumes with moderate right-sided and small left-sided pleural effusions with associated compressive subsegmental atelectasis of the lower lobes.\nThere is also subsegmental atelectasis of the right middle lobe and lingula.\n3.\nTriple vessel coronary artery disease.',
#   'Female',
#   61,
#   '8/7/18 20:43'],
#  [25987652,
#   '1.\nThe bolus of contrast is suboptimal for evaluation of the segmental branches of the pulmonary arteries, but no central emboli to the level of the lobar arteries is noted.\n2.\nClear lungs.',
#   'Male',
#   21,
#   '8/6/18 22:30'],
#  [25944164,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Male',
#   21,
#   '7/18/18 11:21'],
#  [25662476,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo consolidation of pneumonia or acute pulmonary process is noted.\nThere is minimal paraseptal emphysema.\n3.\nCoronary artery disease.\nRecommend secondary prevention of cardiovascular disease and lifestyle modifications as appropriate.',
#   'Male',
#   61,
#   '3/23/18 16:55'],
#  [25554342,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo pneumonia is noted.\n3.\nUnchanged partially calcified and partially thrombosed 1.3 cm right renal artery pseudoaneurysm.',
#   'Female',
#   74,
#   '2/5/18 18:39'],
#  [28718953,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nPatchy areas of groundglass opacification are seen in the periphery of the upper lobes posteriorly in the lower lobes, with more areas of consolidation in the lower lobes consistent with multifocal pneumonia.\nThese findings are commonly reported \nCovid 19 pneumonia, but other infectious processes and inflammatory processes can have similar appearance.\n3.\nFindings of right heart strain with left ventricular inner bulging of the interventricular septum and enlarged main pulmonary arterial trunk measuring 3.5 cm.\nThere is also metallic artifact at the interatrial septum suggesting previous atrial \nseptal defect repair.\nPlease correlate with congenital heart disease history and consider cardiology consultation for right heart strain/pulmonary hypertension.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 9.6 - 16.8 mGy.\nDLP: 621 mGy-cm.',
#   'Male',
#   29,
#   '10/4/21 20:37'],
#  [28652783,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is an enlarged main pulmonary arterial trunk as in the previous exam suggesting pulmonary hypertension.\n2.\nNo acute pulmonary process is noted.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13',
#   'Female',
#   74,
#   '9/10/21 18:03'],
#  [28457601,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild enlargement of the main pulmonary arterial trunk that may indicate pulmonary hypertension.\n2.\nNo acute pulmonary process is noted.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: LS1RADW03E\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.4 - 28.1 mGy.\nDLP: 1813 mGy-cm.The following accession numbers are related to this dose report 28457601:28457602',
#   'Female',
#   81,
#   '6/30/21 17:30'],
#  [28415157,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild enlargement of the main pulmonary arterial trunk measuring 3.5 cm that may indicate pulmonary hypertension.\n2.\nThere is moderate diffuse centrilobular emphysema and severe upper lobes paraseptal emphysema.\nThere is also mild bronchiectasis of the right lung.\nNo consolidation is noted.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 17.2 - 20.5 mGy.\nDLP: 700 mGy-cm.',
#   'Male',
#   72,
#   '6/15/21 17:16'],
#  [28336455,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nCompared to the old exam from 2013, there is mild enlargement of the main pulmonary arterial trunk measuring 3.3 cm that may indicate pulmonary hypertension.\n2.\nExtensive multifocal pneumonia with dense consolidations.\nThere is entire consolidation of the right lower lobe.\nNo cavitation is seen.\nIn the differential diagnosis is community-acquired as well as atypical pneumonia.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 19.5 mGy.\nDLP: 1077 mGy-cm.The following accession numbers are related to this dose report 28336455:28336456',
#   'Female',
#   54,
#   '5/18/21 8:53'],
#  [28332472,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nInterval increase in size of the right hilar mass with confluent extensive lymphadenopathy in the mediastinum surrounding the trachea and extension into the right supraclavicular region.\n3.\nPersistent mass effect over the right pulmonary arteries by the mass and occlusion of the right lower lobe bronchus.\nThere are unchanged left lung pulmonary nodules.\n4.\nInterval placement of a small right-sided chest tube into the large pleural effusion.\nPockets of air are seen within the effusion likely introduced by the catheter, but empyema cannot be excluded.\nNodularity of the pleura suggest malignant \neffusion.\n5.\nNo significant interval change is noted in the osseous metastases.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 12.3 - 17.0 mGy.\nDLP: 746 mGy-cm.',
#   'Male',
#   56,
#   '5/16/21 23:44'],
#  [28226044,
#   'There is no prominent pulmonary embolus.\nThere is a small left lower lobe pulmonary artery branch which is not well opacified.\nThe possibility of a pulmonary embolus, of uncertain age, at this site cannot be fully excluded.\nThis vessel was more \noptimally opacified on the prior study from 09/23/2016.\nDensity at the lung bases may represent atelectasis.\nFollow-up to resolution is recommended.\nLytic process involving the T11 vertebra.\nThis may represent multiple myeloma.\nAbnormality was noted at this region on the MRI study of the thoracic spine dated 07/11/2020.\nThis information was discussed with Dr. Alycia Valente at 5:20 PM on 04-05-2021.\nA Red Document Only actionable finding was communicated and has been documented for ALYCIA M. VALENTE in the PowerConnect Actionable Findings on 4/5/2021 5:20 PM, Message ID 4322371.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW12\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 14.4 mGy.\nDLP: 395 mGy-cm.',
#   'Male',
#   65,
#   '4/5/21 16:16'],
#  [28185275,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is an enlarged main pulmonary artery.\nThis may represent pulmonary hypertension.\n2.\nCardiomegaly, bilateral small pleural effusions, and mild interstitial pulmonary edema.\n3.\nNonspecific mediastinal lymphadenopathy.\nRecommend 3 months follow-up with CT of the chest for stability.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 16.8 mGy.\nDLP: 519 mGy-cm.',
#   'Male',
#   36,
#   '3/20/21 17:26'],
#  [28120608,
#   'There is no pulmonary embolus seen in the proximal major pulmonary arteries.\nHowever, the segmental/subsegmental arterial branches are not well opacified.\nIf clinically indicated, this examination could be repeated in attempt to obtain more optimal \nopacification of the pulmonary arteries.\nThere is no pneumonia.\nPossible subtle emphysematous changes of the lungs.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: LS1RADW06E\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 22.4 mGy.\nDLP: 939 mGy-cm.The following accession numbers are related to this dose report 28120608:28120611',
#   'Female',
#   59,
#   '2/24/21 10:45'],
#  [28033656,
#   '1.\nThe bolus of contrast is suboptimal for evaluation of the subsegmental branches of the pulmonary arteries, but no emboli are noted to the segmental level.\n2.\nNo acute pulmonary process is noted.\n3.\nNonspecific periportal lymphadenopathy that may be due to hepatitis.\nMild splenomegaly.',
#   'Male',
#   62,
#   '1/17/21 9:56'],
#  [27976511,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild prominence of the main pulmonary arterial trunk measuring 3.6 cm that may represent pulmonary hypertension.\n2.\nMild bibasilar subsegmental atelectases.\nNo pneumonia is noted.\nMultiple calcified granulomas in the right lung.\nA 3 mm new nodule is seen in the right upper lobe that is indeterminate.\nSee below recommendations for follow-up:\r\nFleischner Society 2017 Guidelines for Management of Incidentally Detected Pulmonary Nodules in Adults',
#   'Male',
#   64,
#   '12/20/20 14:56'],
#  [27873398,
#   '1.\nThe study is limited by poor concentration of contrast in the pulmonary arteries, but no pulmonary emboli are seen to the lobar level.\nThere is unchanged mild enlargement of the main pulmonary arterial trunk measuring 3.4 cm.\n2.\nSevere right lung emphysema and areas of scarring and atelectasis.\nNo pneumonia or pulmonary edema is seen.\n3.\nStatus post partial left pneumonectomy with unchanged cavitations in the left hemithorax with air-fluid levels.',
#   'Male',
#   74,
#   '11/3/20 16:23'],
#  [27648890,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.\nThere are mild changes of emphysema in the lung apices.\n3.\nSeveral small pulmonary nodules are noted.\nThe largest measures 5 mm in the right lower lobe.\nSee below recommendations for follow-up.\n4.\nCoronary artery calcifications consistent with coronary artery disease.\nRecommend secondary prevention of cardiovascular disease.\nFleischner Society 2017 Guidelines for Management of Incidentally Detected Pulmonary Nodules in Adults',
#   'Male',
#   48,
#   '7/30/20 18:28'],
#  [27552049,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is pulmonary hypertension noted by enlargement of the main pulmonary arterial trunk.\n2.\nBibasilar subsegmental atelectasis.\nNo consolidation is noted.\nThere is a moderate right and small left pleural effusion.',
#   'Female',
#   84,
#   '6/17/20 13:27'],
#  [27437611,
#   "1.\nThere is limited evaluation of the subsegmental branches of the pulmonary arteries due to patient's respiratory motion artifact, but no arterial pulmonary emboli is seen to the segmental level.\n2.\nLarge right-sided pleural effusion with compressive subsegmental atelectasis of the right lower lobe.",
#   'Male',
#   78,
#   '3/23/20 22:37'],
#  [27033481,
#   '1.\nThere is a suboptimal bolus of contrast for evaluation of the pulmonary arteries beyond the lobar arteries, but no central pulmonary emboli to the level of the lobar arteries is noted.\n2.\nMinimal dependent atelectasis of the lung bases.',
#   'Female',
#   36,
#   '10/21/19 8:58'],
#  [27002640,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nSubsegmental atelectasis or scarring in the inferior segment of the lingula.\n3.\nCoronary artery disease noted by calcifications in the left anterior descending coronary artery.\nRecommend secondary prevention of perivascular disease.',
#   'Male',
#   44,
#   '10/7/19 17:54'],
#  [26638439,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nCentrilobular emphysema.\n3.\nRight axillary lymphadenopathy compared to previous exam.\nOther small lymph nodes in the mediastinum including right paraesophageal lymph node are unchanged compared to previous.\n4.\nMild compression fracture of the T8 vertebral body with patchy areas of sclerosis in the vertebral body posteriorly compared to previous exam that may represent a pathologic fracture from metastatic disease.\nRecommend bone scan for further \nassessment of the skeletal system.',
#   'Female',
#   70,
#   '5/9/19 21:36'],
#  [26564025,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nMild dependent atelectasis of the lower lobes.',
#   'Male',
#   89,
#   '4/9/19 18:17'],
#  [26528663,
#   "1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nBibasilar bronchiolitis and consolidations of pneumonia.\nAspiration pneumonia cannot be excluded.\nThere is mild reactive lymphadenopathy.\n3.\nSubacute or acute burst fracture of T6 vertebral body with approximately 75% loss of vertebral body height and retropulsed bone into the spinal canal.\nThere is associated paraspinal soft tissue swelling.\nGiven patient's bilateral leg weakness, \nrecommend MRI of the thoracic spine for assessment of the thoracic spinal cord.\n4.\nUnchanged small pulmonary nodules described in previous CT for lung cancer screening of 09/14/2018.\nRecommend keeping inferiorly lung cancer screening CT schedule.\nA Incidental - UN ED actionable finding has been sent via the PowerConnect Actionable Findings system on 3/26/2019 7:31 PM.\nReceipt of this communication by the responsible provider will be documented in PowerConnect Actionable Findings upon receiving \nacknowledgement, Message ID 3280975",
#   'Male',
#   75,
#   '3/26/19 18:39'],
#  [26452551,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   43,
#   '2/26/19 22:43'],
#  [26395715,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.\n3.\nCardiomegaly with small pericardial effusion.\nTiny bilateral pleural effusions are seen.',
#   'Male',
#   56,
#   '2/1/19 15:37'],
#  [26364155,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   24,
#   '1/18/19 18:29'],
#  [26162356,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo significant interval change in the metastatic lesions to lung.\nThere is better aeration of the right upper lobe compared to the previous exam.\nHowever, there is further thickening with irregularity of the posterior inferior right pleura corresponding to metastatic disease.',
#   'Female',
#   66,
#   '10/22/18 20:06'],
#  [26132303,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   52,
#   '10/9/18 20:59'],
#  [26101082,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo consolidation of pneumonia is noted.',
#   'Female',
#   57,
#   '9/25/18 19:49'],
#  [26070601,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.\nUnchanged peripheral coarse reticulations in both lungs of chronic interstitial lung disease.',
#   'Female',
#   71,
#   '9/12/18 18:43'],
#  [25861769,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\nThere is mild cardiomegaly.\n2.\nDilated esophagus with food particles and hiatus hernia as seen in the previous exam without significant change.\n3.\nBibasilar subsegmental atelectasis.',
#   'Male',
#   67,
#   '6/11/18 21:30'],
#  [25790177,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted.',
#   'Female',
#   27,
#   '5/13/18 11:01'],
#  [25760987,
#   "1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nThere is a small left lower lobe consolidation likely representing pneumonia.\n3.\nSeveral indeterminate small pulmonary nodules are noted with the largest measuring 7 mm in the right lower lobe.\nThe 7 mm right lower lobe pulmonary nodule is present in the visualized portions of the lungs of the CT of the abdomen of May 10, 2017 and \nis unchanged.\nThe others are outside the field-of-view of the previous abdomen CT.\nGiven patient's history of breast carcinoma, metastatic disease cannot be excluded.\nRecommend follow-up noncontrast CT of the chest in 3 months for stability.\nA Incidental - MM ED actionable finding has been sent via the PowerScribe 360 | Critical Result system on 5/1/2018 9:10 PM.\nReceipt of this communication by the responsible provider will be documented in PowerScribe 360 upon receiving acknowledgement, \nMessage ID 2834438",
#   'Female',
#   54,
#   '5/1/18 19:38'],
#  [25756935,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nNo acute pulmonary process is noted compared to previous exam.\nThere is unchanged elevation of the right hemidiaphragm with compressive subsegmental atelectasis of the right lower lobe.\nThere is a narrowing of the posterior segmental bronchus of \nthe right lower lobe an endobronchial lesion or extrinsic compressive lesion of the right bronchus cannot be excluded.\nRecommend pulmonary consultation for possible bronchoscopy for further evaluation.\nA Incidental - UN ED actionable finding has been sent via the PowerScribe 360 | Critical Result system on 4/30/2018 5:32 PM.\nReceipt of this communication by the responsible provider will be documented in PowerScribe 360 upon receiving acknowledgement, \nMessage ID 2832538',
#   'Female',
#   71,
#   '4/30/18 16:34'],
#  [25729055,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nUnchanged lymphadenopathy and mild fibrotic changes of the lung bases.\nNo new consolidation or acute pulmonary process is noted.\n3.\nGallstones as in the previous exam.',
#   'Female',
#   69,
#   '4/19/18 11:44'],
#  [28734432,
#   '1.\nLimited evaluation of the subsegmental branches of the pulmonary arteries due to respiratory motion artifact, but no emboli are noted to the pulmonary arterial segmental level.\n2.\nThere is new thrombosis of the left subclavian vein and proximal axillary vein since CT angiogram of the neck of 08/30/2021.\n3.\nRight hilar fullness with loss of volume of the right lung as in the previous exam.\nThere is nodular bronchial filling of the right lower lobe that may be due to infectious process or progression of of lung cancer.\n4.\nCompared to the outside CT of 06/29/2020, there is a new left adrenal gland metastasis and increase in the size of the right adrenal gland metastasis.\nFindings were discussed with Dr. Sherman at 11:54 PM on the day of exam.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: FS1HPACSW13\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 16.9 - 19.7 mGy.\nDLP: 1372 mGy-cm.',
#   'Female',
#   79,
#   '10/9/21 22:53'],
#  [28472424,
#   '1.\nThere is no evidence of pulmonary arterial emboli.\n2.\nCardiomegaly, moderate to large bilateral pleural effusions, and interstitial pulmonary edema.\nIf this radiology report contains a blank impression section, it is an incomplete radiology report.\nPlease contact the interpreting radiologist or applicable radiology division as soon as possible to obtain the completed interpretation.\nWorkstation ID: LS1RADW03E\nUp-to-date CT equipment and radiation dose reduction techniques were employed.\nCTDIvol: 2.3 - 30.8 mGy.\nDLP: 2038 mGy-cm.The following accession numbers are related to this dose report 28472424:28472422',
#   'Male',
#   83,
#   '7/7/21 12:06'],
#  [28434987,
# ...
#   'Male',
#   49,
#   '11/10/19 18:14'],
#  [27089133,
#   'Clear lungs.\nNo pulmonary embolus.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   51,
#   '11/10/19 17:38'],
#  [27089066,
#   '1.\nNo pulmonary embolus.\n2.\nModerate to severe upper lobe predominant emphysema and postradiation changes in the right upper lobe and chest wall.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   63,
#   '11/10/19 16:04'],
#  [27076898,
#   'There is no pulmonary embolus seen.\nThere is a moderate right-sided pleural fluid collection present.\nThere is atelectasis/infiltrate in the right lower lobe.\nFollow-up to complete resolution is essential.\nPossible subcarinal lymphadenopathy.\nDiffuse edema/fluid in the wall of the chest and abdomen consistent with anasarca.\nThere is free fluid present in the abdomen and pelvis.\nCholelithiasis.',
#   'Female',
#   59,
#   '11/5/19 19:49'],
#  [27057612,
#   '1.\nNo evidence for pulmonary embolus.\n2.\nRight-sided aortic arch with left descending thoracic aorta.\n3.\nDistal esophageal wall thickening likely due to underlying GERD.\n4.\nNo pneumonia.',
#   'Male',
#   30,
#   '10/29/19 15:52'],
#  [27042867,
#   'No evidence of pulmonary emboli.\nI, James Kelly, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:David Radcliffe, M.D.',
#   'Female',
#   68,
#   '10/23/19 18:13'],
#  [27038789,
#   '1.\nNo evidence of pulmonary emboli.\n2.\nLeft upper and lower lobe pneumonia superimposed on background post radiation change secondary to previous stage III left lower lobe adenocarcinoma.\nSmall left-sided pleural effusion.\n3.\nLimited evaluation for disease recurrence secondary to the acute process.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:David Radcliffe, M.D.',
#   'Male',
#   64,
#   '10/22/19 14:51'],
#  [27017172,
#   "Examination is somewhat limited due to patient's respiratory produced motion artifact, but no pulmonary emboli or acute pulmonary process is noted.",
#   'Male',
#   26,
#   '10/13/19 20:22'],
#  [27007355,
#   '1.\nNo evidence of a pulmonary emboli.\n2.\nInnumerable new and enlarging pulmonary nodules involving all lobes measuring as well as mediastinal lymphadenopathy consistent with metastatic disease.\n3.\nSmall right and trace left-sided pleural effusions.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:David Radcliffe, M.D.',
#   'Female',
#   62,
#   '10/9/19 10:50'],
#  [26961422,
#   '1.\nBilateral lower lobe pneumonia, right greater than left likely secondary to aspiration.\n2.\nNo pulmonary embolus\r\nI, Dennis Coughlin, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   66,
#   '9/21/19 1:16'],
#  [26940572,
#   '1.\nNo proximal pulmonary embolus.\n2.\nDiffusely fluid-filled ileum and large bowel may represent enteritis versus mild ileus.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Roberto Diaz-Kutcher, M.D.',
#   'Male',
#   54,
#   '9/12/19 19:03'],
#  [26937627,
#   "1.\nNo evidence of pulmonary embolus.\n2.\nNo explanation for patient's chest pain.",
#   'Female',
#   18,
#   '9/12/19 5:34'],
#  [26818717,
#   '1.\nNo pulmonary emboli.\n2.\nPatchy bilateral ground glass opacities with interlobular septal thickening and prominent lymph nodes.\nIn the appropriate clinical setting this could represent pulmonary edema versus an atypical pneumonia given the bronchial wall thickening.\n3.\nNo acute abnormality in the abdomen or pelvis.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Joelle Wazen, MD',
#   'Female',
#   43,
#   '7/23/19 20:30'],
#  [26789983,
#   "1.\nNo pulmonary embolus.\n2.\nAgain noted is a dominant right lower lobe mass with improvement in the postobstructive atelectasis/pneumonia.\n3.\nMultiple bilateral soft tissue pulmonary nodules, in keeping with patient's known diagnosis of metastatic cancer.\nAdditionally, in the newly aerated right lower lobe there is nodular interlobular and intralobular septal thickening concerning for lymphangitic carcinomatosis.\n4.\nIncreased bulky right subclavian bulky lymphadenopathy, with improvement in the mediastinal and hilar lymphadenopathy.\nI, Carolyn Dupuis, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Derek Chicarilli, MD",
#   'Female',
#   56,
#   '7/11/19 13:36'],
#  [26747835,
#   "1.\nThe segmental and subsegmental branches of the lower lobes, lingula, and right middle lobe are not evaluable due to patient's respiratory motion artifact, but no central emboli are noted.\n2.\nMild subsegmental atelectasis of the lower lobes.\n3.\nMild compression fractures of indeterminate age of T7 and T8, but more recent than CT of the thoracic spine from March 2018.",
#   'Female',
#   89,
#   '6/23/19 22:06'],
#  [26746833,
#   "1.\nThe examination is limited for evaluation of the subsegmental segmental branches of the lower lobes due to patient's produced respiratory motion artifact, but no filling defects are noted to the segmental level to suggest central emboli.\n2.\nNo consolidation, pneumothorax or pulmonary edema is seen.",
#   'Male',
#   75,
#   '6/22/19 17:09'],
#  [26621080,
#   '1.\nNo pulmonary embolus.\n2.\nModerate size hiatal hernia.\n3.\nIncidental note is made of thymic hyperplasia.\nI, Sarwat Hussain, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Derek Chicarilli, MD',
#   'Female',
#   35,
#   '5/3/19 0:38'],
#  [26546576,
#   '1.\nNo pulmonary embolus.\n2.\nRight upper lobe pneumonia.\nI, Dennis Coughlin, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Derek Chicarilli, MD',
#   'Female',
#   17,
#   '4/3/19 2:41'],
#  [26462931,
#   '1.\nNo pulmonary embolus.\n2.\nAcute displaced left anterolateral second, fourth and fifth rib fractures.\nNo pneumothorax.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   76,
#   '3/3/19 17:12'],
#  [26393632,
#   'No pulmonary embolus.\nI, Dennis Coughlin, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   37,
#   '2/1/19 3:37'],
#  [26390560,
#   '1.\nNo pulmonary embolus up to the segmental level.\n2.\nHypoinflated lungs with diffuse groundglass opacity suggestive of subsegmental atelectasis.\n3.\nHepatic steatosis.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   43,
#   '1/30/19 22:21'],
#  [26384426,
#   '1.\nNo pulmonary embolus.\n2.\nRedemonstration of moderate to large bilateral pleural effusions with bibasilar compressive atelectasis and a small pericardial effusion.\n3.\nExpected postoperative appearance in the abdomen small loculated perihepatic collections with foci of air.\nNo large, drainable fluid collection identified.\nI, Dennis Coughlin, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   83,
#   '1/29/19 5:16'],
#  [26379952,
#   '1.\nNo pulmonary embolus up to the segmental level.\n2.\nNo acute abnormality in the chest, abdomen and pelvis\nI, Amina Saghir, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   54,
#   '1/26/19 19:58'],
#  [26364445,
#   'No pulmonary embolus.\nEssentially clear lungs.\nI, Sarwat Hussain, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   61,
#   '1/19/19 5:15'],
#  [26364444,
#   'No pulmonary embolus up to the segmental level.\nClear lungs.\nI, Sarwat Hussain, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   20,
#   '1/19/19 4:56'],
#  [26356326,
#   'No pulmonary embolus up to the segmental level.\nDependent atelectasis, otherwise clear lungs.',
#   'Female',
#   14,
#   '1/16/19 10:22'],
#  [26316429,
#   "1.\nNo pulmonary embolus.\n2.\nSmall right pleural effusion and bibasilar compressive atelectasis.\n3.\nPatchy areas of groundglass attenuation in the right upper lobe may represent edema or developing consolidation.\n4.\nSubtle cortical defect within the posterior aspect of the left 10th rib could reflect a nondisplaced fracture.\nCorrelation with the area of patient's tenderness is recommended.\n5.\nA 3.5 cm thyroid nodule.\nNonemergent neck ultrasound is recommended for further characterization.\nA Incidental - UN ED actionable finding has been sent via the PowerScribe 360 | Critical Result system on 12/30/2018 10:03 AM.\nReceipt of this communication by the responsible provider will be documented in PowerScribe 360 upon receiving \nacknowledgement, Message ID 3156057\nI, Hao Lo, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS",
#   'Male',
#   76,
#   '12/30/18 8:46'],
#  [26315839,
#   'No pulmonary embolus.\nEssentially clear lungs.\nI, Hao Lo, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   64,
#   '12/29/18 14:59'],
#  [26315580,
#   'No pulmonary embolus.\nEssentially clear lungs.\nI, Hao Lo, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   81,
#   '12/29/18 9:44'],
#  [26287515,
#   '1.\nNo pulmonary embolus.\nClear lungs.\n2.\nSoft tissue mass in the anterior mediastinum measuring up to 5.5 cm.\nDifferential considerations include thymoma versus lymphoma with thymoma considered more likely.\n3.\nBorderline aneurysmal dilatation of the ascending aorta measuring up to 4 cm.',
#   'Male',
#   70,
#   '12/16/18 4:04'],
#  [26277708,
#   '1.\nNo pulmonary embolus.\n2.\nSevere emphysema.\nI, Dennis Coughlin, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   42,
#   '12/12/18 5:31'],
#  [26271281,
#   '1.\nNo pulmonary embolus up to the segmental level.\n2.\nFindings of fluid overload including bilateral pleural effusions and anasarca.\nI, Francesco Massari, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   67,
#   '12/10/18 5:54'],
#  [26271155,
#   'No pulmonary embolus.\nClear lungs.\nI, Erica Ghosh, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   18,
#   '12/9/18 21:25'],
#  [26270546,
#   '1.\nNo pulmonary embolus.\n2.\nVery subtle micronodules measuring less than 3 mm in a tree-in-bud distribution are seen in the right apex and could be infectious versus inflammatory in origin.\n3.\nDiffusely enlarged thyroid.\nCorrelation with lab values and clinical examination is recommended.\nI, Francesco Massari, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   68,
#   '12/9/18 4:51'],
#  [26270502,
#   'No pulmonary embolus.\nClear lungs.\nI, Francesco Massari, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Female',
#   57,
#   '12/9/18 2:17'],
#  [26270434,
#   'No pulmonary embolus up to the segmental level.\nClear lungs.\nI, Francesco Massari, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Venkatesh Arumugan Murugan, MBBS',
#   'Male',
#   65,
#   '12/8/18 23:37'],
#  [26214403,
#   'No evidence for pulmonary embolus.',
#   'Male',
#   42,
#   '11/13/18 18:22'],
#  [26142419,
#   '1.\nNo evidence of pulmonary embolus.\n2.\nClear lungs.\nI, Hao Lo, have reviewed the examination and concur with the findings as reported or so edited.\nResident/Fellow:Bryan OSullivan-Murphy, M.D.',
#   'Female',
#   36,
#   '10/14/18 11:02'],
#  [26118988,
#   '1.\nNo pulmonary embolus.\n2.\nPostradiation changes are redemonstrated in the left axilla with a few slightly prominent, unchanged axillary lymph nodes.\n3.\nLeft upper lobe pulmonary nodules measuring up to 8 mm are new from the prior PET/CT.\nThese subpleural nodules are immediately subjacent to the post radiation changes in the left chest wall and could represent the sequela of prior radiation therapy.\nInfectious and neoplastic etiologies are also considered.\nA short-term follow-up CT in 3 months is recommended to evaluate for resolution/progression.',
#   'Male',
#   41,
#   '10/3/18 12:11'],
#  [26113208,
#   '1.\nNo pulmonary embolus.\n2.\nMultifocal sclerotic and lytic osseous lesions, suspicious for metastatic disease as described.\nPathologic fracture of the spinous processes of T4 vertebra.\n3.\nAsymmetric right breast tissue.\nDedicated breast imaging is recommended.',
#   'Female',
#   67,
#   '10/1/18 12:35'],
#  [26109499,
#   '1.\nNo pulmonary embolus or rib fractures.\n2.\nGroundglass nodules in a tree-in-bud distribution are seen in the posterior aspect of the right upper lobe.\nThis is suggestive of atypical pneumonia.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.',
#   'Male',
#   50,
#   '9/28/18 15:57'],
#  [26106460,
#   '1.\nNo pulmonary embolus.\n2.\nBibasilar subsegmental atelectasis, a consolidation in the right lower lobe cannot be excluded.\nThere is trace right and small left pleural effusion.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.',
#   'Female',
#   46,
#   '9/27/18 15:19'],
#  [26103611,
#   '1.\nNo pulmonary embolus.\n2.\nRight middle lobe subsegmental atelectasis and minimal consolidation.\nI, Byron Chen, have reviewed the examination and concur with the findings as reported or so edited.',
#   'Female',
#   62,
#   '9/26/18 15:30'],
#  [26101116,
#   'No pulmonary embolus up to the segmental level.\nEssentially clear lungs.\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.',
#   'Female',
#   21,
#   '9/25/18 21:05'],
#  [26100926,
#   '1.\nNo pulmonary embolus.\n2.\nSlightly prominent lower cervical, right lower interlobar and left hilar lymph nodes of uncertain clinical significance.\nShort term follow-up chest CT in 3 months is recommended to ensure stability.\nA Incidental - MM ED actionable finding has been sent via the PowerScribe 360 | Critical Result system on 9/25/2018 5:57 PM.\nReceipt of this communication by the responsible provider will be documented in PowerScribe 360 upon receiving acknowledgement, Message ID 3026910\r\nI, Jorge M Medina, have reviewed the examination and concur with the findings as reported or so edited.',
#   'Male',
#   63,
#   '9/25/18 17:26'],
#  [26089211,
#   'No pulmonary embolus.\nModerate centrilobular emphysema.\nI, Carolyn Dupuis, have reviewed the examination and concur with the findings as reported or so edited.',
#   'Female',
#   76,
#   '9/20/18 13:01'],
#  ...]

# %%
df_pn_impressions = pd.DataFrame(pn_impressions, columns=['Accession Number', 'Impression', 'Parient Sex', 'Patient Age', 'Ordered Date'])
df_pn_impressions = df_pn_impressions.sample(frac=1)
df_pp_impressions = pd.DataFrame(pp_impressions, columns=['Accession Number', 'Impression', 'Parient Sex', 'Patient Age', 'Ordered Date'])
df_pp_impressions = df_pp_impressions.sample(frac=1)

# %%
df_pn_impressions.to_csv("data/potential_negative_impressions.csv", index=False)
df_pp_impressions.to_csv("data/potential_positive_impressions.csv", index=False)

# %% [markdown]
# ## Creating txt files

# %%
# for index, row in df_pn_impressions.iterrows():
#     an = row['Accession Number']
#     f = open('pn_impression_txt_files/'+str(an)+'_imp.txt', 'w')
#     f.write(row['Report Text'])
#     f.close()
